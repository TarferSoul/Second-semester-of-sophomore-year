# %%
import math
from collections import Counter, defaultdict
from docx import Document
import os
import json
import random

# %%
def read_docx(file_path):
    """读取DOCX文件并返回其中的文本内容"""
    doc = Document(file_path)
    text = []
    for para in doc.paragraphs:
        text.append(para.text)
    return ''.join(text)

def collect_statistics(text):
    """统计汉字、标点符号和空格的频率"""
    char_count = Counter(text)
    total_chars = sum(char_count.values())
    return char_count, total_chars

# %%
def calculate_entropy(filtered_text, order=0):
    if order == 0:
        # 0阶马尔可夫模型：每个字符独立选择
        char_count = Counter(filtered_text)
        total_chars = sum(char_count.values())
        entropy = 0
        for count in char_count.values():
            probability = count / total_chars
            entropy -= probability * math.log2(probability)
        return entropy
    else:
        # 高阶马尔可夫模型
        storage = defaultdict(Counter)
        total_cal = len(filtered_text) - order

        for i in range(total_cal):
            prefix = filtered_text[i:i + order]
            next_char = filtered_text[i + order]
            storage[prefix][next_char] += 1

        entropy = 0
        for prefix, suffix_counts in storage.items():
            prefix_total = sum(suffix_counts.values())
            for count in suffix_counts.values():
                probability = count / prefix_total
                entropy -= (prefix_total / total_cal) * probability * math.log2(probability)

        return entropy

# %%
def markov_model(text, order):
    """构建马尔可夫模型并输出模型状态和转移概率"""
    filtered_text = text
    storage = defaultdict(Counter)

    for i in range(len(filtered_text) - order):
        prefix = filtered_text[i:i + order]
        next_char = filtered_text[i + order]
        storage[prefix][next_char] += 1

    total_storage = sum(sum(suffix_counts.values()) for suffix_counts in storage.values())
    model = {}
    for prefix, suffix_counts in storage.items():
        prefix_total = sum(suffix_counts.values())
        model[prefix] = {char: count / prefix_total for char, count in suffix_counts.items()}

    return model, total_storage

# %%
def print_markov_model(model):
    """打印马尔可夫模型的状态和转移概率"""
    for prefix, transitions in model.items():
        print(f"State: {prefix}")
        for char, prob in transitions.items():
            print(f"  {char}: {prob:.4f}")

# %% [markdown]
# 由于数据过少，导致只有零阶熵的数据比较准确。
# 参考文献：
# 在国内最早冯志伟先生用了将近 10 年的时间，进行手工查频，从小到大地逐步扩大统计的规模，建立了 6 个不同容量的汉字频度表，最后根据这些不同的汉字频度表，逐步地扩大汉字的容量，终于在 70 年代末期首次计算出了在不考虑上下文影响的前提下汉字信息熵的值是 9.65 比特……黄萱菁等在 4 年的《人民日报》语料的基础上，所求得的零阶熵、一阶熵、二阶熵分别为 9.62，6.18 和 4.89 比特。 刘源给出汉字熵的计算结果是9.71 比特。 孙帆等基于词的语言模型估计方法比基于字的直接计算方法得到了汉字熵的更为精确的估计，其熵值为 5.31 比特。

# %%
Text_file = 'Zhengfei_Ren_Email.docx'
Text = read_docx(Text_file)

Text_stats, elon_total = collect_statistics(Text)
print("Zhengfei_Ren_Email Statistics:")
print(Text_stats)
# Out:
# Zhengfei_Ren_Email Statistics:
# Counter({'，': 164, '的': 83, '。': 57, '是': 52, '一': 51, '人': 42, '才': 36, '们': 34, '就': 34, '有': 33, '我': 32, '要': 31, '他': 31, '在': 29, '不': 29, '、': 24, '个': 21, '专': 21, '家': 21, '工': 19, '来': 19, '成': 18, '大': 18, '界': 17, '能': 17, '高': 15, '时': 15, '以': 15, '定': 15, '如': 15, '学': 15, '到': 15, '为': 14, '上': 14, '也': 14, '自': 13, '去': 13, '多': 13, '会': 12, '可': 12, '这': 12, '了': 12, '业': 11, '边': 11, '力': 11, '没': 11, '作': 10, '么': 10, '理': 10, '很': 10, '长': 10, '级': 10, '“': 10, '”': 10, '…': 10, '华': 9, '司': 8, '先': 8, '全': 8, '产': 8, '员': 8, '果': 8, '主': 8, '生': 8, '实': 8, '件': 8, '己': 7, '优': 7, '秀': 7, '清': 7, '公': 7, '方': 7, '所': 7, '当': 7, '什': 7, '愿': 7, '意': 7, '中': 7, '出': 7, '然': 7, '部': 7, '合': 7, '小': 7, '做': 7, '端': 6, '对': 6, '0': 6, '储': 6, '备': 6, '务': 6, '内': 6, '经': 6, '位': 6, '事': 6, '行': 6, '比': 6, '只': 6, '面': 6, '让': 6, '找': 6, '献': 6, '价': 6, '和': 6, '新': 6, '题': 6, '咖': 6, '啡': 6, '开': 6, '平': 6, '创': 5, '任': 5, '术': 5, '2': 5, '招': 5, '确': 5, '领': 5, '适': 5, '些': 5, '从': 5, '？': 5, '因': 5, '走': 5, '环': 5, '第': 5, '点': 5, '好': 5, '发': 5, '评': 5, '把': 5, '喝': 5, '过': 5, '；': 5, '文': 5, '起': 5, '解': 5, '知': 5, '交': 5, '流': 5, '台': 5, '技': 4, '用': 4, '讲': 4, '年': 4, '建': 4, '格': 4, '聘': 4, '研': 4, '宽': 4, '得': 4, '想': 4, '转': 4, '本': 4, '医': 4, '后': 4, '通': 4, '蛋': 4, '算': 4, '强': 4, '看': 4, '都': 4, '最': 4, '指': 4, '管': 4, '直': 4, '道': 4, '路': 4, '功': 4, '破': 4, '二': 4, '爱': 4, '岗': 4, '机': 4, '同': 4, '目': 4, '网': 4, '间': 4, '核': 4, '调': 4, '1': 4, '数': 4, '系': 4, '师': 4, '再': 4, '项': 4, '性': 4, '样': 4, '量': 4, '程': 4, '容': 4, '关': 4, '现': 4, '于': 4, '跨': 4, '思': 4, '非': 3, '立': 3, '库': 3, '但': 3, '楚': 3, '究': 3, '索': 3, '世': 3, '品': 3, '无': 3, '那': 3, '划': 3, '否': 3, '源': 3, '相': 3, '物': 3, '进': 3, '向': 3, '断': 3, '其': 3, '此': 3, '干': 3, '践': 3, '层': 3, '验': 3, '激': 3, '热': 3, '认': 3, '贡': 3, '识': 3, '别': 3, '入': 3, '职': 3, '帖': 3, '沟': 3, '字': 3, '担': 3, '心': 3, '错': 3, '问': 3, '资': 3, '还': 3, '往': 3, '升': 3, '两': 3, '历': 3, '罗': 3, '水': 3, '次': 3, '袖': 3, '炸': 3, '统': 3, '皮': 3, '粥': 3, '境': 3, '条': 3, '矛': 3, '盾': 3, '决': 3, '策': 3, '选': 3, 'F': 3, 'C': 3, '基': 3, '而': 3, '软': 3, '造': 3, '给': 3, '写': 3, '听': 3, '声': 3, '互': 3, '始': 2, '使': 2, '标': 2, '话': 2, '拘': 2, '获': 2, '取': 2, '许': 2, '探': 2, '明': 2, '围': 2, '收': 2, '候': 2, '首': 2, '科': 2, '白': 2, '质': 2, '计': 2, '包': 2, '着': 2, '设': 2, '类': 2, '垂': 2, '循': 2, '拔': 2, '励': 2, '住': 2, '应': 2, '该': 2, '与': 2, '结': 2, '重': 2, '视': 2, '挥': 2, '批': 2, '回': 2, '门': 2, '签': 2, '化': 2, '整': 2, '前': 2, '呢': 2, '短': 2, '超': 2, '你': 2, '准': 2, '线': 2, '体': 2, '埋': 2, '初': 2, '庚': 2, '启': 2, '校': 2, '5': 2, '书': 2, '权': 2, '三': 2, '某': 2, '突': 2, '述': 2, '镇': 2, '规': 2, '仅': 2, '社': 2, '代': 2, '框': 2, '孩': 2, '懂': 2, '太': 2, '易': 2, '史': 2, '踩': 2, '坑': 2, '择': 2, '贯': 2, '彻': 2, '节': 2, '财': 2, '里': 2, 'P': 2, '站': 2, '精': 2, '慢': 2, '光': 2, '硬': 2, '烟': 2, '囱': 2, '搞': 2, '土': 2, '壤': 2, '畅': 2, '欲': 2, '言': 2, '涌': 2, '英': 2, '雄': 2, '制': 2, '值': 2, '诉': 2, '报': 2, '善': 2, '群': 2, '形': 2, '式': 2, '聊': 2, '良': 2, '头': 2, '天': 2, '引': 2, '动': 2, '更': 2, '读': 2, '滚': 2, '正': 1, '组': 1, '3': 1, '7': 1, '月': 1, '8': 1, '日': 1, '允': 1, '已': 1, '努': 1, '限': 1, '范': 1, '缩': 1, '孙': 1, '山': 1, '国': 1, '售': 1, '莫': 1, '贝': 1, '克': 1, '电': 1, '曾': 1, '牙': 1, '虽': 1, '习': 1, '神': 1, '等': 1, '固': 1, '法': 1, '括': 1, '朝': 1, '假': 1, '美': 1, '元': 1, '终': 1, '或': 1, '列': 1, '逐': 1, '步': 1, '积': 1, '累': 1, '难': 1, '提': 1, '何': 1, '留': 1, '踏': 1, '若': 1, '兴': 1, '趣': 1, '怨': 1, '悔': 1, '信': 1, '寻': 1, '判': 1, '哪': 1, '少': 1, '差': 1, '异': 1, '班': 1, '齐': 1, '即': 1, '段': 1, '被': 1, '淘': 1, '汰': 1, '拿': 1, '快': 1, '谈': 1, '复': 1, '需': 1, '严': 1, '丝': 1, '缝': 1, '%': 1, '模': 1, '糊': 1, '集': 1, '议': 1, '歪': 1, '瓜': 1, '裂': 1, '枣': 1, '特': 1, '殊': 1, '降': 1, '熊': 1, '庆': 1, '涯': 1, '伦': 1, '录': 1, '绩': 1, '分': 1, '钱': 1, '钟': 1, '园': 1, '接': 1, '授': 1, '钻': 1, '透': 1, '绕': 1, '城': 1, '墙': 1, '放': 1, '药': 1, '地': 1, '阐': 1, '构': 1, '并': 1, '变': 1, '帅': 1, '绝': 1, '市': 1, '矩': 1, ...

# %%
Text_entropy_0 = calculate_entropy(Text, 0)
Text_entropy_3 = calculate_entropy(Text, 3)
Text_entropy_5 = calculate_entropy(Text, 5)
print(f"\nText Entropy (0th order): {Text_entropy_0}")
print(f"Text Entropy (3rd order): {Text_entropy_3}")
print(f"Text Entropy (5th order): {Text_entropy_5}")
# Out:
# Text Entropy (0th order): 8.11198715230113
# Text Entropy (3rd order): 0.14993218305713354
# Text Entropy (5th order): 0.017173222905156053

# %%
orders = [0, 3, 5]
for order in orders:
    print(f"\nZhengfei_Ren_Email Markov Model (Order {order}):")
    elon_model, elon_total_ngrams = markov_model(Text, order)
    print_markov_model(elon_model)

    with open(f'Zhengfei_Ren_Email Markov Model (Order {order}).txt', 'w', encoding='utf-8',) as f:
        f.write(str(elon_model))
        f.close()
# Out:
# Zhengfei_Ren_Email Markov Model (Order 0):
# State:
#   华: 0.0033
#   为: 0.0052
#   创: 0.0019
#   始: 0.0007
#   人: 0.0156
#   任: 0.0019
#   正: 0.0004
#   非: 0.0011
#   在: 0.0107
#   高: 0.0056
#   端: 0.0022
#   技: 0.0015
#   术: 0.0019
#   才: 0.0133
#   使: 0.0007
#   用: 0.0015
#   工: 0.0070
#   作: 0.0037
#   组: 0.0004
#   对: 0.0022
#   标: 0.0007
#   会: 0.0044
#   上: 0.0052
#   的: 0.0308
#   讲: 0.0015
#   话: 0.0007
#   2: 0.0019
#   0: 0.0022
#   3: 0.0004
#   年: 0.0015
#   7: 0.0004
#   月: 0.0004
#   8: 0.0004
#   日: 0.0004
#   一: 0.0189
#   、: 0.0089
#   我: 0.0119
#   们: 0.0126
#   要: 0.0115
#   建: 0.0015
#   立: 0.0011
#   个: 0.0078
#   自: 0.0048
#   己: 0.0026
#   储: 0.0022
#   备: 0.0022
#   库: 0.0011
#   ，: 0.0608
#   不: 0.0107
#   拘: 0.0007
#   格: 0.0015
#   获: 0.0007
#   取: 0.0007
#   优: 0.0026
#   秀: 0.0026
#   但: 0.0011
#   招: 0.0019
#   聘: 0.0015
#   时: 0.0056
#   清: 0.0026
#   楚: 0.0011
#   公: 0.0026
#   司: 0.0030
#   业: 0.0041
#   务: 0.0022
#   边: 0.0041
#   界: 0.0063
#   允: 0.0004
#   许: 0.0007
#   内: 0.0022
#   研: 0.0015
#   究: 0.0011
#   探: 0.0007
#   索: 0.0011
#   。: 0.0211
#   已: 0.0004
#   经: 0.0022
#   明: 0.0007
#   确: 0.0019
#   努: 0.0004
#   力: 0.0041
#   有: 0.0122
#   限: 0.0004
#   范: 0.0004
#   围: 0.0007
#   领: 0.0019
#   先: 0.0030
#   世: 0.0011
#   是: 0.0193
#   全: 0.0030
#   方: 0.0026
#   位: 0.0022
#   所: 0.0026
#   以: 0.0056
#   产: 0.0030
#   品: 0.0011
#   收: 0.0007
#   缩: 0.0004
#   可: 0.0044
#   适: 0.0019
#   当: 0.0026
#   宽: 0.0015
#   些: 0.0019
#   也: 0.0052
#   得: 0.0015
#   无: 0.0011
#   那: 0.0011
#   么: 0.0037
#   候: 0.0007
#   首: 0.0007
#   划: 0.0011
#   定: 0.0056
#   理: 0.0037
#   想: 0.0015
#   什: 0.0026
#   这: 0.0044
#   专: 0.0078
#   员: 0.0030
#   他: 0.0115
#   否: 0.0011
#   愿: 0.0026
#   意: 0.0026
#   从: 0.0019
#   事: 0.0022
#   ？: 0.0019
#   如: 0.0056
#   果: 0.0030
#   转: 0.0015
#   行: 0.0022
#   比: 0.0022
#   孙: 0.0004
#   中: 0.0026
#   山: 0.0004
#   本: 0.0015
#   学: 0.0056
#   医: 0.0015
#   后: 0.0015
#   来: 0.0070
#   国: 0.0004
#   出: 0.0026
#   售: 0.0004
#   莫: 0.0004
#   贝: 0.0004
#   克: 0.0004
#   电: 0.0004
#   源: 0.0011
#   主: 0.0030
#   曾: 0.0004
#   牙: 0.0004
#   科: 0.0007
#   生: 0.0030
#   因: 0.0019
#   相: 0.0011
#   通: 0.0015
#   虽: 0.0004
#   然: 0.0026
#   习: 0.0004
#   神: 0.0004
#   蛋: 0.0015
#   白: 0.0007
#   质: 0.0007
#   物: 0.0011
#   等: 0.0004
#   计: 0.0007
#   算: 0.0015
#   能: 0.0063
#   很: 0.0037
#   强: 0.0015
#   固: 0.0004
#   看: 0.0015
#   法: 0.0004
#   只: 0.0022
#   都: 0.0015
#   进: 0.0011
#   包: 0.0007
#   括: 0.0004
#   到: 0.0056
#   就: 0.0126
#   朝: 0.0004
#   着: 0.0007
#   假: 0.0004
#   设: 0.0007
#   向: 0.0011
#   断: 0.0011
#   美: 0.0004
#   元: 0.0004
#   最: 0.0015
#   终: 0.0004
#   部: 0.0026
#   指: 0.0015
#   面: 0.0022
#   管: 0.0015
#   类: 0.0007
#   或: 0.0004
#   其: 0.0011
#   此: 0.0011
#   列: 0.0004
#   干: 0.0011
#   走: 0.0019
#   垂: 0.0007
#   直: 0.0015
#   循: 0.0007
#   环: 0.0019
#   实: 0.0030
#   践: 0.0011
#   逐: 0.0004
#   步: 0.0004
#   成: 0.0067
#   长: 0.0037
#   道: 0.0015
#   路: 0.0015
#   没: 0.0041
#   层: 0.0011
#   功: 0.0015
#   验: 0.0011
#   积: 0.0004
#   累: 0.0004
#   难: 0.0004
#   破: 0.0015
#   提: 0.0004
#   拔: 0.0007
#   二: 0.0015
#   激: 0.0011
#   励: 0.0007
#   让: 0.0022
#   找: 0.0022
#   热: 0.0011
#   爱: 0.0015
#   岗: 0.0015
#   何: 0.0004
#   留: 0.0004
#   住: 0.0007
#   认: 0.0011
#   第: 0.0019
#   点: 0.0019
#   应: 0.0007
#   该: 0.0007
#   踏: 0.0004
#   若: 0.0004
#   兴: 0.0004
#   趣: 0.0004
#   好: 0.0019
#   与: 0.0007
#   机: 0.0015
#   结: 0.0007
#   合: 0.0026
#   了: 0.0044
#   怨: 0.0004
#   悔: 0.0004
#   重: 0.0007
#   视: 0.0007
#   发: 0.0019
#   挥: 0.0007
#   同: 0.0015
#   贡: 0.0011
#   献: 0.0022
#   去: 0.0048
#   评: 0.0019
#   价: 0.0022
#   批: 0.0007
#   级: 0.0037
#   家: 0.0078
#   信: 0.0004
#   识: 0.0011
#   别: 0.0011
#   和: 0.0022
#   入: 0.0011
#   职: 0.0011
#   新: 0.0022
#   寻: 0.0004
#   把: 0.0019
#   题: 0.0022
#   目: 0.0015
#   网: 0.0015
#   回: 0.0007
#   帖: 0.0011
#   喝: 0.0019
#   咖: 0.0022
#   啡: 0.0022
#   沟: 0.0011
#   判: 0.0004
#   哪: 0.0004
#   门: 0.0007
#   多: 0.0048
#   少: 0.0004
#   签: 0.0007
#   字: 0.0011
#   差: 0.0004
#   异: 0.0004
#   化: 0.0007
#   班: 0.0004
#   整: 0.0007
#   齐: 0.0004
#   前: 0.0007
#   呢: 0.0007
#   担: 0.0011
#   心: 0.0011
#   错: 0.0011
#   即: 0.0004
#   短: 0.0007
#   间: 0.0015
#   问: 0.0011
#   过: 0.0019
#   段: 0.0004
#   被: 0.0004
#   淘: 0.0004
#   汰: 0.0004
#   拿: 0.0004
#   资: 0.0011
#   ；: 0.0019
#   还: 0.0011
#   往: 0.0011
#   升: 0.0011
#   快: 0.0004
#   超: 0.0007
#   你: 0.0007
#   准: 0.0007
#   线: 0.0007
#   谈: 0.0004
#   复: 0.0004
#   核: 0.0015
#   两: 0.0011
#   需: 0.0004
#   调: 0.0015
#   严: 0.0004
#   丝: 0.0004
#   缝: 0.0004
#   1: 0.0015
#   %: 0.0004
#   模: 0.0004
#   糊: 0.0004
#   集: 0.0004
#   体: 0.0007
#   议: 0.0004
#   埋: 0.0007
#   “: 0.0037
#   歪: 0.0004
#   瓜: 0.0004
#   裂: 0.0004
#   枣: 0.0004
#   ”: 0.0037
#   特: 0.0004
#   殊: 0.0004
#   降: 0.0004
#   大: 0.0067
#   数: 0.0015
#   系: 0.0015
#   熊: 0.0004
#   庆: 0.0004
#   初: 0.0007
#   历: 0.0011
#   罗: 0.0011
#   庚: 0.0007
#   开: 0.0022
#   启: 0.0007
#   水: 0.0011
#   平: 0.0022
#   涯: 0.0004
#   伦: 0.0004
#   校: 0.0007
#   录: 0.0004
#   绩: 0.0004
#   5: 0.0007
#   分: 0.0004
#   钱: 0.0004
#   钟: 0.0004
#   书: 0.0007
#   文: 0.0019
#   师: 0.0015
#   园: 0.0004
#   次: 0.0011
#   再: 0.0015
#   接: 0.0004
#   授: 0.0004
#   权: 0.0007
#   三: 0.0007
#   袖: 0.0011
#   起: 0.0019
#   某: 0.0007
#   项: 0.0015
#   钻: 0.0004
#   透: 0.0004
#   解: 0.0019
#   突: 0.0007
#   绕: 0.0004
#   城: 0.0004
#   墙: 0.0004
#   放: 0.0004
#   炸: 0.0011
#   药: 0.0004
#   地: 0.0004
#   统: 0.0011
#   性: 0.0015
#   阐: 0.0004
#   述: 0.0007
#   构: 0.0004
#   皮: 0.0011
#   粥: 0.0011
#   样: 0.0015
#   并: 0.0004
#   变: 0.0004
#   帅: 0.0004
#   绝: 0.0004
#   小: 0.0026
#   镇: 0.0007
#   市: 0.0004
#   规: 0.0007
#   矩: 0.0004
#   约: 0.0004
#   束: 0.0004
#   仅: 0.0007
#   父: 0.0004
#   母: 0.0004
#   社: 0.0007
#   境: 0.0011
#   代: 0.0007
#   朋: 0.0004
#   友: 0.0004
#   它: 0.0004
#   量: 0.0015
#   程: 0.0015
#   艺: 0.0004
#   条: 0.0011
#   框: 0.0007
#   孩: 0.0007
#   懂: 0.0007
#   太: 0.0007
#   件: 0.0030
#   容: 0.0015
#   易: 0.0007
#   抓: 0.0004
#   矛: 0.0011
#   盾: 0.0011
#   史: 0.0007
#   喜: 0.0004
#   欢: 0.0004
#   踩: 0.0007
#   坑: 0.0007
#   摔: 0.0004
#   知: 0.0019
#   决: 0.0011
#   策: 0.0011
#   做: 0.0026
#   叫: 0.0004
#   情: 0.0004
#   胡: 0.0004
#   选: 0.0011
#   择: 0.0007
#   贯: 0.0007
#   彻: 0.0007
#   考: 0.0004
#   节: 0.0007
#   省: 0.0004
#   财: 0.0007
#   几: 0.0004
#   名: 0.0004
#   牌: 0.0004
#   里: 0.0007
#   派: 0.0004
#   洲: 0.0004
#   P: 0.0007
#   F: 0.0011
#   C: 0.0011
#   基: 0.0011
#   站: 0.0007
#   板: 0.0004
#   …: 0.0037
#   O: 0.0004
#   精: 0.0007
#   慢: 0.0007
#   关: 0.0015
#   空: 0.0004
#   军: 0.0004
#   令: 0.0004
#   而: 0.0011
#   晓: 0.0004
#   者: 0.0004
#   现: 0.0015
#   博: 0.0004
#   士: 0.0004
#   够: 0.0004
#   交: 0.0019
#   流: 0.0019
#   台: 0.0019
#   便: 0.0004
#   于: 0.0015
#   跨: 0.0015
#   光: 0.0007
#   换: 0.0004
#   硬: 0.0007
#   软: 0.0011
#   越: 0.0004
#   烟: 0.0007
#   囱: 0.0007
#   搞: 0.0007
#   朵: 0.0004
#   云: 0.0004
#   融: 0.0004
#   四: 0.0004
#   造: 0.0011
#   土: 0.0007
#   壤: 0.0007
#   畅: 0.0007
#   欲: 0.0007
#   言: 0.0007
#   思: 0.0015
#   涌: 0.0007
#   英: 0.0007
#   雄: 0.0007
#   倍: 0.0004
#   制: 0.0007
#   靠: 0.0004
#   培: 0.0004
#   养: 0.0004
#   杯: 0.0004
#   吸: 0.0004
#   宇: 0.0004
#   宙: 0.0004
#   给: 0.0011
#   负: 0.0004
#   责: 0.0004
#   拉: 0.0004
#   郎: 0.0004
#   配: 0.0004
#   由: 0.0004
#   度: 0.0004
#   显: 0.0004
#   值: 0.0007
#   投: 0.0004
#   诉: 0.0007
#   写: 0.0011
#   邮: 0.0004
#   听: 0.0011
#   倾: 0.0004
#   纪: 0.0004
#   报: 0.0007
#   帮: 0.0004
#   助: 0.0004
#   安: 0.0004
#   排: 0.0004
#   际: 0.0004
#   熟: 0.0004
#   悉: 0.0004
#   善: 0.0007
#   团: 0.0004
#   老: 0.0004
#   导: 0.0004
#   群: 0.0007
#   众: 0.0004
#   声: 0.0011
#   音: 0.0004
#   互: 0.0011
#   种: 0.0004
#   形: 0.0007
#   式: 0.0007
#   聊: 0.0007
#   室: 0.0004
#   讨: 0.0004
#   论: 0.0004
#   烈: 0.0004
#   区: 0.0004
#   片: 0.0004
#   骂: 0.0004
#   贵: 0.0004
#   僧: 0.0004
#   西: 0.0004
#   汉: 0.0004
#   张: 0.0004
#   良: 0.0007
#   桥: 0.0004
#   头: 0.0007
#   天: 0.0007
#   引: 0.0007
#   动: 0.0007
#   效: 0.0004
#   率: 0.0004
#   表: 0.0004
#   更: 0.0007
#   读: 0.0007
#   半: 0.0004
#   感: 0.0004
#   黄: 0.0004
#   茶: 0.0004
#   屋: 0.0004
#   号: 0.0004
#   召: 0.0004
#   涉: 0.0004
#   及: 0.0004
#   贴: 0.0004
#   查: 0.0004
#   阅: 0.0004
#   今: 0.0004
#   汇: 0.0004
#   晰: 0.0004
#   滚: 0.0007
#   陈: 0.0004
#   谢: 0.0004
#   离: 0.0004
#   继: 0.0004
#   辈: 0.0004
#
# Zhengfei_Ren_Email Markov Model (Order 3):
# State: 华为创
#   始: 1.0000
# State: 为创始
#   人: 1.0000
# State: 创始人
#   任: 1.0000
# State: 始人任
#   正: 1.0000
# State: 人任正
#   非: 1.0000
# State: 任正非
#   在: 1.0000
# State: 正非在
#   华: 1.0000
# State: 非在华
#   为: 1.0000
# State: 在华为
#   高: 1.0000
# State: 华为高
#   端: 1.0000
# State: 为高端
#   技: 1.0000
# State: 高端技
#   术: 1.0000
# State: 端技术
#   人: 1.0000
# State: 技术人
#   才: 1.0000
# State: 术人才
#   使: 0.5000
#   在: 0.5000
# State: 人才使
#   用: 1.0000
# State: 才使用
#   工: 1.0000
# State: 使用工
#   作: 1.0000
# State: 用工作
#   组: 1.0000
# State: 工作组
#   对: 1.0000
# State: 作组对
#   标: 1.0000
# State: 组对标
#   会: 1.0000
# State: 对标会
#   上: 1.0000
# State: 标会上
#   的: 1.0000
# State: 会上的
#   讲: 1.0000
# State: 上的讲
#   话: 1.0000
# State: 的讲话
#   2: 1.0000
# State: 讲话2
#   0: 1.0000
# State: 话20
#   2: 1.0000
# State: 202
#   3: 1.0000
# State: 023
#   年: 1.0000
# State: 23年
#   7: 1.0000
# State: 3年7
#   月: 1.0000
# State: 年7月
#   2: 1.0000
# State: 7月2
#   8: 1.0000
# State: 月28
#   日: 1.0000
# State: 28日
#   一: 1.0000
# State: 8日一
#   、: 1.0000
# State: 日一、
#   我: 1.0000
# State: 一、我
#   们: 1.0000
# State: 、我们
#   要: 0.5000
#   公: 0.5000
# State: 我们要
#   建: 0.3750
#   努: 0.1250
#   重: 0.1250
#   创: 0.2500
#   形: 0.1250
# State: 们要建
#   立: 1.0000
# State: 要建立
#   一: 1.0000
# State: 建立一
#   个: 1.0000
# State: 立一个
#   自: 0.6667
#   高: 0.3333
# State: 一个自
#   己: 1.0000
# State: 个自己
#   的: 1.0000
# State: 自己的
#   高: 0.5000
#   人: 0.2500
#   兴: 0.2500
# State: 己的高
#   端: 1.0000
# State: 的高端
#   人: 1.0000
# State: 高端人
#   才: 1.0000
# State: 端人才
#   储: 0.6667
#   全: 0.3333
# State: 人才储
#   备: 1.0000
# State: 才储备
#   库: 1.0000
# State: 储备库
#   ，: 1.0000
# State: 备库，
#   不: 0.5000
#   只: 0.5000
# State: 库，不
#   拘: 1.0000
# State: ，不拘
#   一: 1.0000
# State: 不拘一
#   格: 1.0000
# State: 拘一格
#   获: 0.5000
#   降: 0.5000
# State: 一格获
#   取: 1.0000
# State: 格获取
#   优: 1.0000
# State: 获取优
#   秀: 1.0000
# State: 取优秀
#   人: 1.0000
# State: 优秀人
#   才: 1.0000
# State: 秀人才
#   ，: 0.1667
#   都: 0.1667
#   的: 0.1667
#   ？: 0.1667
#   涌: 0.3333
# State: 人才，
#   但: 0.5000
#   不: 0.5000
# State: 才，但
#   在: 1.0000
# State: ，但在
#   招: 1.0000
# State: 但在招
#   聘: 1.0000
# State: 在招聘
#   时: 1.0000
# State: 招聘时
#   要: 0.5000
#   可: 0.5000
# State: 聘时要
#   讲: 1.0000
# State: 时要讲
#   清: 1.0000
# State: 要讲清
#   楚: 1.0000
# State: 讲清楚
#   公: 0.5000
#   我: 0.5000
# State: 清楚公
#   司: 1.0000
# State: 楚公司
#   的: 1.0000
# State: 公司的
#   业: 0.5000
#   主: 0.5000
# State: 司的业
#   务: 1.0000
# State: 的业务
#   边: 0.5000
#   范: 0.5000
# State: 业务边
#   界: 1.0000
# State: 务边界
#   ，: 1.0000
# State: 边界，
#   允: 0.5000
#   讲: 0.5000
# State: 界，允
#   许: 1.0000
# State: ，允许
#   在: 1.0000
# State: 允许在
#   边: 1.0000
# State: 许在边
#   界: 1.0000
# State: 在边界
#   内: 1.0000
# State: 边界内
#   研: 0.2000
#   专: 0.4000
#   的: 0.2000
#   来: 0.2000
# State: 界内研
#   究: 1.0000
# State: 内研究
#   探: 1.0000
# State: 研究探
#   索: 1.0000
# State: 究探索
#   。: 1.0000
# State: 探索。
#   公: 1.0000
# State: 索。公
#   司: 1.0000
# State: 。公司
#   已: 0.5000
#   指: 0.5000
# State: 公司已
#   经: 1.0000
# State: 司已经
#   明: 1.0000
# State: 已经明
#   确: 1.0000
# State: 经明确
#   ，: 1.0000
# State: 明确，
#   我: 1.0000
# State: 确，我
#   们: 1.0000
# State: ，我们
#   要: 0.4167
#   产: 0.0833
#   不: 0.0833
#   就: 0.0833
#   的: 0.0833
#   直: 0.0833
#   强: 0.0833
#   “: 0.0833
# State: 们要努
#   力: 1.0000
# State: 要努力
#   在: 1.0000
# State: 努力在
#   有: 1.0000
# State: 力在有
#   限: 1.0000
# State: 在有限
#   的: 1.0000
# State: 有限的
#   业: 1.0000
# State: 限的业
#   务: 1.0000
# State: 业务范
#   围: 1.0000
# State: 务范围
#   内: 1.0000
# State: 范围内
#   领: 1.0000
# State: 围内领
#   先: 1.0000
# State: 内领先
#   世: 1.0000
# State: 领先世
#   界: 1.0000
# State: 先世界
#   ，: 1.0000
# State: 世界，
#   不: 0.5000
#   他: 0.5000
# State: 界，不
#   是: 1.0000
# State: ，不是
#   在: 0.3333
#   我: 0.3333
#   一: 0.3333
# State: 不是在
#   全: 1.0000
# State: 是在全
#   方: 1.0000
# State: 在全方
#   位: 1.0000
# State: 全方位
#   领: 1.0000
# State: 方位领
#   先: 1.0000
# State: 位领先
#   。: 1.0000
# State: 领先。
#   所: 1.0000
# State: 先。所
#   以: 1.0000
# State: 。所以
#   ，: 1.0000
# State: 所以，
#   我: 0.7500
#   现: 0.2500
# State: 以，我
#   们: 1.0000
# State: 我们产
#   品: 1.0000
# State: 们产品
#   的: 1.0000
# State: 产品的
#   边: 1.0000
# State: 品的边
#   界: 1.0000
# State: 的边界
#   是: 0.5000
#   可: 0.5000
# State: 边界是
#   收: 0.5000
#   什: 0.5000
# State: 界是收
#   缩: 1.0000
# State: 是收缩
#   的: 1.0000
# State: 收缩的
#   ，: 1.0000
# State: 缩的，
#   研: 1.0000
# State: 的，研
#   究: 1.0000
# State: ，研究
#   的: 1.0000
# State: 研究的
#   边: 1.0000
# State: 究的边
#   界: 1.0000
# State: 边界可
#   以: 1.0000
# State: 界可以
#   适: 1.0000
# State: 可以适
#   当: 1.0000
# State: 以适当
#   宽: 0.5000
#   模: 0.5000
# State: 适当宽
#   一: 1.0000
# State: 当宽一
#   些: 1.0000
# State: 宽一些
#   ，: 1.0000
# State: 一些，
#   也: 1.0000
# State: 些，也
#   不: 1.0000
# State: ，也不
#   是: 0.5000
#   用: 0.5000
# State: 也不是
#   宽: 1.0000
# State: 不是宽
#   得: 1.0000
# State: 是宽得
#   无: 1.0000
# State: 宽得无
#   边: 1.0000
# State: 得无边
#   。: 1.0000
# State: 无边。
#   那: 1.0000
# State: 边。那
#   么: 1.0000
# State: 。那么
#   ，: 1.0000
# State: 那么，
#   招: 1.0000
# State: 么，招
#   聘: 1.0000
# State: ，招聘
#   的: 1.0000
# State: 招聘的
#   时: 0.5000
#   系: 0.5000
# State: 聘的时
#   候: 1.0000
# State: 的时候
#   ，: 1.0000
# State: 时候，
#   首: 0.5000
#   贯: 0.5000
# State: 候，首
#   先: 1.0000
# State: ，首先
#   要: 1.0000
# State: 首先要
#   划: 1.0000
# State: 先要划
#   定: 1.0000
# State: 要划定
#   一: 1.0000
# State: 划定一
#   个: 1.0000
# State: 定一个
#   业: 1.0000
# State: 一个业
#   务: 1.0000
# State: 个业务
#   边: 1.0000
# State: 界，讲
#   清: 1.0000
# State: ，讲清
#   楚: 1.0000
# State: 清楚我
#   们: 1.0000
# State: 楚我们
#   的: 1.0000
# State: 我们的
#   理: 0.5000
#   专: 0.5000
# State: 们的理
#   想: 1.0000
# State: 的理想
#   是: 1.0000
# State: 理想是
#   什: 1.0000
# State: 想是什
#   么: 1.0000
# State: 是什么
#   、: 0.3333
#   。: 0.3333
#   ，: 0.3333
# State: 什么、
#   边: 1.0000
# State: 么、边
#   界: 1.0000
# State: 、边界
#   是: 1.0000
# State: 界是什
#   么: 1.0000
# State: 什么。
#   不: 1.0000
# State: 么。不
#   在: 1.0000
# State: 。不在
#   我: 1.0000
# State: 不在我
#   们: 1.0000
# State: 在我们
#   这: 0.5000
#   招: 0.5000
# State: 我们这
#   个: 1.0000
# State: 们这个
#   边: 1.0000
# State: 这个边
#   界: 1.0000
# State: 个边界
#   内: 1.0000
# State: 界内专
#   业: 1.0000
# State: 内专业
#   的: 1.0000
# State: 专业的
#   人: 1.0000
# State: 业的人
#   员: 0.5000
#   才: 0.5000
# State: 的人员
#   ，: 1.0000
# State: 人员，
#   他: 0.5000
#   只: 0.5000
# State: 员，他
#   是: 1.0000
# State: ，他是
#   否: 1.0000
# State: 他是否
#   愿: 1.0000
# State: 是否愿
#   意: 1.0000
# State: 否愿意
#   从: 1.0000
# State: 愿意从
#   事: 1.0000
# State: 意从事
#   在: 1.0000
# State: 从事在
#   边: 1.0000
# State: 事在边
#   界: 1.0000
# State: 界内的
#   工: 1.0000
# State: 内的工
#   作: 1.0000
# State: 的工作
#   ？: 0.3333
#   岗: 0.6667
# State: 工作？
#   如: 1.0000
# State: 作？如
#   果: 1.0000
# State: ？如果
#   他: 1.0000
# State: 如果他
#   愿: 0.2500
#   确: 0.5000
#   一: 0.2500
# State: 果他愿
#   意: 1.0000
# State: 他愿意
#   ，: 1.0000
# State: 愿意，
#   转: 1.0000
# State: 意，转
#   行: 1.0000
# State: ，转行
#   是: 1.0000
# State: 转行是
#   可: 1.0000
# State: 行是可
#   以: 1.0000
# State: 是可以
#   的: 1.0000
# State: 可以的
#   。: 1.0000
# State: 以的。
#   比: 1.0000
# State: 的。比
#   如: 1.0000
# State: 。比如
#   ，: 1.0000
# State: 比如，
#   孙: 0.2500
#   清: 0.2500
#   光: 0.2500
#   把: 0.2500
# State: 如，孙
#   中: 1.0000
# State: ，孙中
#   山: 1.0000
# State: 孙中山
#   本: 1.0000
# State: 中山本
#   是: 1.0000
# State: 山本是
#   学: 1.0000
# State: 本是学
#   医: 1.0000
# State: 是学医
#   的: 1.0000
# State: 学医的
#   ，: 1.0000
# State: 医的，
#   先: 1.0000
# State: 的，先
#   是: 1.0000
# State: ，先是
#   医: 1.0000
# State: 先是医
#   人: 1.0000
# State: 是医人
#   ，: 1.0000
# State: 医人，
#   后: 1.0000
# State: 人，后
#   来: 1.0000
# State: ，后来
#   医: 1.0000
# State: 后来医
#   国: 1.0000
# State: 来医国
#   。: 1.0000
# State: 医国。
#   我: 1.0000
# State: 国。我
#   们: 1.0000
# State: 。我们
#   公: 0.1250
#   要: 0.1250
#   朝: 0.1250
#   是: 0.1250
#   在: 0.1250
#   不: 0.1250
#   可: 0.2500
# State: 我们公
#   司: 1.0000
# State: 们公司
#   出: 0.5000
#   要: 0.5000
# State: 公司出
#   售: 1.0000
# State: 司出售
#   的: 1.0000
# State: 出售的
#   莫: 1.0000
# State: 售的莫
#   贝: 1.0000
# State: 的莫贝
#   克: 1.0000
# State: 莫贝克
#   电: 1.0000
# State: 贝克电
#   源: 1.0000
# State: 克电源
#   公: 1.0000
# State: 电源公
#   司: 1.0000
# State: 源公司
#   的: 1.0000
# State: 司的主
#   力: 1.0000
# State: 的主力
#   曾: 1.0000
# State: 主力曾
#   是: 1.0000
# State: 力曾是
#   牙: 1.0000
# State: 曾是牙
#   科: 1.0000
# State: 是牙科
#   医: 1.0000
# State: 牙科医
#   生: 1.0000
# State: 科医生
#   ，: 1.0000
# State: 医生，
#   因: 1.0000
# State: 生，因
#   为: 1.0000
# State: ，因为
#   技: 0.5000
#   人: 0.5000
# State: 因为技
#   术: 1.0000
# State: 为技术
#   是: 1.0000
# State: 技术是
#   相: 1.0000
# State: 术是相
#   通: 1.0000
# State: 是相通
#   的: 1.0000
# State: 相通的
#   ，: 1.0000
# State: 通的，
#   他: 1.0000
# State: 的，他
#   虽: 1.0000
# State: ，他虽
#   然: 1.0000
# State: 他虽然
#   学: 1.0000
# State: 虽然学
#   习: 1.0000
# State: 然学习
#   神: 1.0000
# State: 学习神
#   经: 1.0000
# State: 习神经
#   学: 1.0000
# State: 神经学
#   、: 1.0000
# State: 经学、
#   蛋: 1.0000
# State: 学、蛋
#   白: 1.0000
# State: 、蛋白
#   质: 1.0000
# State: 蛋白质
#   生: 1.0000
# State: 白质生
#   物: 1.0000
# State: 质生物
#   学: 1.0000
# State: 生物学
#   等: 1.0000
# State: 物学等
#   ，: 1.0000
# State: 学等，
#   但: 1.0000
# State: 等，但
#   计: 1.0000
# State: ，但计
#   算: 1.0000
# State: 但计算
#   能: 1.0000
# State: 计算能
#   力: 1.0000
# State: 算能力
#   也: 1.0000
# State: 能力也
#   很: 1.0000
# State: 力也很
#   强: 1.0000
# State: 也很强
#   。: 1.0000
# State: 很强。
#   所: 1.0000
# State: 强。所
#   以: 1.0000
# State: 我们不
#   要: 1.0000
# State: 们不要
#   对: 0.3333
#   担: 0.3333
#   给: 0.3333
# State: 不要对
#   人: 1.0000
# State: 要对人
#   才: 1.0000
# State: 对人才
#   有: 0.5000
#   的: 0.5000
# State: 人才有
#   固: 1.0000
# State: 才有固
#   定: 1.0000
# State: 有固定
#   看: 1.0000
# State: 固定看
#   法: 1.0000
# State: 定看法
#   。: 1.0000
# State: 看法。
#   我: 1.0000
# State: 法。我
#   们: 1.0000
# State: 库，只
#   要: 1.0000
# State: ，只要
#   是: 1.0000
# State: 只要是
#   优: 1.0000
# State: 要是优
#   秀: 1.0000
# State: 是优秀
#   人: 1.0000
# State: 人才都
#   可: 1.0000
# State: 才都可
#   以: 1.0000
# State: 都可以
#   进: 1.0000
# State: 可以进
#   来: 1.0000
# State: 以进来
#   ，: 1.0000
# State: 进来，
#   包: 1.0000
# State: 来，包
#   括: 1.0000
# State: ，包括
#   非: 1.0000
# State: 包括非
#   边: 1.0000
# State: 括非边
#   界: 1.0000
# State: 非边界
#   内: 1.0000
# State: 的人才
#   愿: 0.5000
#   库: 0.5000
# State: 人才愿
#   意: 1.0000
# State: 才愿意
#   到: 1.0000
# State: 愿意到
#   边: 1.0000
# State: 意到边
#   界: 1.0000
# State: 到边界
#   内: 1.0000
# State: 界内来
#   工: 1.0000
# State: 内来工
#   作: 1.0000
# State: 来工作
#   ，: 1.0000
# State: 工作，
#   我: 1.0000
# State: 作，我
#   们: 1.0000
# State: 我们就
#   愿: 1.0000
# State: 们就愿
#   意: 1.0000
# State: 就愿意
#   要: 1.0000
# State: 愿意要
#   。: 1.0000
# State: 意要。
#   我: 1.0000
# State: 要。我
#   们: 1.0000
# State: 我们朝
#   着: 1.0000
# State: 们朝着
#   假: 1.0000
# State: 朝着假
#   设: 1.0000
# State: 着假设
#   的: 1.0000
# State: 假设的
#   方: 1.0000
# State: 设的方
#   向: 1.0000
# State: 的方向
#   ，: 1.0000
# State: 方向，
#   不: 1.0000
# State: 向，不
#   断: 1.0000
# State: ，不断
#   探: 0.5000
#   储: 0.5000
# State: 不断探
#   索: 1.0000
# State: 断探索
#   ，: 1.0000
# State: 探索，
#   不: 1.0000
# State: 索，不
#   断: 1.0000
# State: 不断储
#   备: 1.0000
# State: 断储备
#   。: 1.0000
# State: 储备。
#   我: 1.0000
# State: 备。我
#   们: 1.0000
# State: 我们是
#   储: 1.0000
# State: 们是储
#   备: 1.0000
# State: 是储备
#   人: 1.0000
# State: 储备人
#   才: 1.0000
# State: 备人才
#   ，: 1.0000
# State: 才，不
#   储: 1.0000
# State: ，不储
#   备: 1.0000
# State: 不储备
#   美: 1.0000
# State: 储备美
#   元: 1.0000
# State: 备美元
#   ，: 1.0000
# State: 美元，
#   最: 1.0000
# State: 元，最
#   终: 1.0000
# State: ，最终
#   储: 1.0000
# State: 最终储
#   备: 1.0000
# State: 终储备
#   出: 1.0000
# State: 储备出
#   自: 1.0000
# State: 备出自
#   己: 1.0000
# State: 出自己
#   的: 1.0000
# State: 己的人
#   才: 1.0000
# State: 人才库
#   。: 1.0000
# State: 才库。
#   当: 1.0000
# State: 库。当
#   然: 1.0000
# State: 。当然
#   ，: 1.0000
# State: 当然，
#   高: 1.0000
# State: 然，高
#   端: 1.0000
# State: ，高端
#   人: 0.5000
#   技: 0.5000
# State: 人才全
#   部: 1.0000
# State: 才全部
#   是: 1.0000
# State: 全部是
#   指: 1.0000
# State: 部是指
#   技: 1.0000
# State: 是指技
#   术: 1.0000
# State: 指技术
#   方: 1.0000
# State: 技术方
#   面: 1.0000
# State: 术方面
#   ，: 1.0000
# State: 方面，
#   管: 0.5000
#   就: 0.5000
# State: 面，管
#   理: 1.0000
# State: ，管理
#   类: 1.0000
# State: 管理类
#   或: 0.5000
#   的: 0.5000
# State: 理类或
#   其: 1.0000
# State: 类或其
#   他: 1.0000
# State: 或其他
#   行: 1.0000
# State: 其他行
#   业: 1.0000
# State: 他行业
#   不: 1.0000
# State: 行业不
#   在: 1.0000
# State: 业不在
#   此: 1.0000
# State: 不在此
#   列: 1.0000
# State: 在此列
#   ，: 1.0000
# State: 此列，
#   管: 1.0000
# State: 列，管
#   理: 1.0000
# State: 理类的
#   干: 1.0000
# State: 类的干
#   部: 1.0000
# State: 的干部
#   走: 1.0000
# State: 干部走
#   垂: 1.0000
# State: 部走垂
#   直: 1.0000
# State: 走垂直
#   循: 1.0000
# State: 垂直循
#   环: 1.0000
# State: 直循环
#   、: 1.0000
# State: 循环、
#   在: 1.0000
# State: 环、在
#   实: 1.0000
# State: 、在实
#   践: 1.0000
# State: 在实践
#   中: 1.0000
# State: 实践中
#   逐: 1.0000
# State: 践中逐
#   步: 1.0000
# State: 中逐步
#   成: 1.0000
# State: 逐步成
#   长: 1.0000
# State: 步成长
#   的: 1.0000
# State: 成长的
#   道: 0.3333
#   土: 0.6667
# State: 长的道
#   路: 1.0000
# State: 的道路
#   ，: 1.0000
# State: 道路，
#   没: 1.0000
# State: 路，没
#   有: 1.0000
# State: ，没有
#   层: 0.5000
#   专: 0.5000
# State: 没有层
#   层: 1.0000
# State: 有层层
#   的: 1.0000
# State: 层层的
#   实: 1.0000
# State: 层的实
#   践: 1.0000
# State: 的实践
#   成: 0.5000
#   经: 0.5000
# State: 实践成
#   功: 1.0000
# State: 践成功
#   经: 1.0000
# State: 成功经
#   验: 1.0000
# State: 功经验
#   积: 1.0000
# State: 经验积
#   累: 1.0000
# State: 验积累
#   ，: 1.0000
# State: 积累，
#   很: 1.0000
# State: 累，很
#   难: 1.0000
# State: ，很难
#   有: 1.0000
# State: 很难有
#   破: 1.0000
# State: 难有破
#   格: 1.0000
# State: 有破格
#   提: 1.0000
# State: 破格提
#   拔: 1.0000
# State: 格提拔
#   的: 1.0000
# State: 提拔的
#   可: 1.0000
# State: 拔的可
#   能: 1.0000
# State: 的可能
#   。: 1.0000
# State: 可能。
#   二: 1.0000
# State: 能。二
#   、: 1.0000
# State: 。二、
#   对: 1.0000
# State: 二、对
#   优: 1.0000
# State: 、对优
#   秀: 1.0000
# State: 对优秀
#   人: 1.0000
# State: 人才的
#   激: 0.3333
#   识: 0.3333
#   责: 0.3333
# State: 才的激
#   励: 1.0000
# State: 的激励
#   ，: 1.0000
# State: 激励，
#   最: 1.0000
# State: 励，最
#   主: 1.0000
# State: ，最主
#   要: 1.0000
# State: 最主要
#   是: 0.5000
#   的: 0.5000
# State: 主要是
#   让: 1.0000
# State: 要是让
#   他: 1.0000
# State: 是让他
#   们: 1.0000
# State: 让他们
#   能: 1.0000
# State: 他们能
#   找: 1.0000
# State: 们能找
#   到: 1.0000
# State: 能找到
#   自: 1.0000
# State: 找到自
#   己: 1.0000
# State: 到自己
#   热: 1.0000
# State: 自己热
#   爱: 1.0000
# State: 己热爱
#   的: 1.0000
# State: 热爱的
#   工: 0.5000
#   岗: 0.5000
# State: 爱的工
#   作: 1.0000
# State: 工作岗
#   位: 1.0000
# State: 作岗位
#   。: 0.3333
#   的: 0.3333
#   ，: 0.3333
# State: 岗位。
#   如: 1.0000
# State: 位。如
#   何: 1.0000
# State: 。如何
#   留: 1.0000
# State: 如何留
#   住: 1.0000
# State: 何留住
#   优: 1.0000
# State: 留住优
#   秀: 1.0000
# State: 住优秀
#   人: 1.0000
# State: 人才？
#   我: 1.0000
# State: 才？我
#   认: 1.0000
# State: ？我认
#   为: 1.0000
# State: 我认为
#   ，: 0.5000
#   讲: 0.5000
# State: 认为，
#   物: 1.0000
# State: 为，物
#   质: 1.0000
# State: ，物质
#   激: 1.0000
# State: 物质激
#   励: 1.0000
# State: 质激励
#   不: 1.0000
# State: 激励不
#   是: 1.0000
# State: 励不是
#   最: 1.0000
# State: 不是最
#   主: 1.0000
# State: 是最主
#   要: 1.0000
# State: 主要的
#   ，: 1.0000
# State: 要的，
#   第: 1.0000
# State: 的，第
#   一: 1.0000
# State: ，第一
#   点: 1.0000
# State: 第一点
#   应: 1.0000
# State: 一点应
#   该: 1.0000
# State: 点应该
#   是: 1.0000
# State: 应该是
#   他: 1.0000
# State: 该是他
#   能: 1.0000
# State: 是他能
#   找: 1.0000
# State: 他能找
#   到: 1.0000
# State: 爱的岗
#   位: 1.0000
# State: 的岗位
#   ，: 1.0000
# State: 岗位，
#   当: 0.5000
#   一: 0.5000
# State: 位，当
#   他: 1.0000
# State: ，当他
#   热: 1.0000
# State: 当他热
#   爱: 1.0000
# State: 他热爱
#   时: 1.0000
# State: 热爱时
#   ，: 1.0000
# State: 爱时，
#   就: 1.0000
# State: 时，就
#   会: 1.0000
# State: ，就会
#   踏: 1.0000
# State: 就会踏
#   实: 1.0000
# State: 会踏实
#   工: 1.0000
# State: 踏实工
#   作: 1.0000
# State: 实工作
#   。: 1.0000
# State: 工作。
#   若: 1.0000
# State: 作。若
#   果: 1.0000
# State: 。若果
#   自: 1.0000
# State: 若果自
#   己: 1.0000
# State: 果自己
#   的: 1.0000
# State: 己的兴
#   趣: 1.0000
# State: 的兴趣
#   爱: 1.0000
# State: 兴趣爱
#   好: 1.0000
# State: 趣爱好
#   与: 1.0000
# State: 爱好与
#   工: 1.0000
# State: 好与工
#   作: 1.0000
# State: 与工作
#   机: 1.0000
# State: 工作机
#   会: 1.0000
# State: 作机会
#   相: 1.0000
# State: 机会相
#   结: 1.0000
# State: 会相结
#   合: 1.0000
# State: 相结合
#   了: 1.0000
# State: 结合了
#   ，: 1.0000
# State: 合了，
#   他: 1.0000
# State: 了，他
#   就: 1.0000
# State: ，他就
#   会: 0.5000
#   知: 0.5000
# State: 他就会
#   无: 1.0000
# State: 就会无
#   怨: 1.0000
# State: 会无怨
#   无: 1.0000
# State: 无怨无
#   悔: 1.0000
# State: 怨无悔
#   。: 1.0000
# State: 无悔。
#   因: 1.0000
# State: 悔。因
#   此: 1.0000
# State: 。因此
#   ，: 1.0000
# State: 因此，
#   我: 1.0000
# State: 此，我
#   们: 1.0000
# State: 们要重
#   视: 1.0000
# State: 要重视
#   这: 1.0000
# State: 重视这
#   些: 1.0000
# State: 视这些
#   人: 1.0000
# State: 这些人
#   才: 1.0000
# State: 些人才
#   在: 1.0000
# State: 人才在
#   工: 0.5000
#   适: 0.5000
# State: 才在工
#   作: 1.0000
# State: 在工作
#   岗: 1.0000
# State: 岗位的
#   发: 1.0000
# State: 位的发
#   挥: 1.0000
# State: 的发挥
#   ，: 1.0000
# State: 发挥，
#   同: 1.0000
# State: 挥，同
#   时: 1.0000
# State: ，同时
#   也: 1.0000
# State: 同时也
#   在: 1.0000
# State: 时也在
#   贡: 1.0000
# State: 也在贡
#   献: 1.0000
# State: 在贡献
#   上: 1.0000
# State: 贡献上
#   去: 1.0000
# State: 献上去
#   评: 1.0000
# State: 上去评
#   价: 1.0000
# State: 去评价
#   他: 1.0000
# State: 评价他
#   。: 1.0000
# State: 价他。
#   公: 0.5000
#   我: 0.5000
# State: 他。公
#   司: 1.0000
# State: 公司指
#   定: 1.0000
# State: 司指定
#   了: 1.0000
# State: 指定了
#   一: 1.0000
# State: 定了一
#   批: 1.0000
# State: 了一批
#   高: 1.0000
# State: 一批高
#   级: 1.0000
# State: 批高级
#   专: 1.0000
# State: 高级专
#   家: 1.0000
# State: 级专家
#   ，: 0.2500
#   交: 0.2500
#   担: 0.2500
#   要: 0.2500
# State: 专家，
#   信: 1.0000
# State: 家，信
#   任: 1.0000
# State: ，信任
#   他: 1.0000
# State: 信任他
#   们: 1.0000
# State: 任他们
#   对: 1.0000
# State: 他们对
#   人: 1.0000
# State: 们对人
#   才: 1.0000
# State: 才的识
#   别: 1.0000
# State: 的识别
#   和: 1.0000
# State: 识别和
#   评: 1.0000
# State: 别和评
#   价: 1.0000
# State: 和评价
#   ，: 1.0000
# State: 评价，
#   去: 1.0000
# State: 价，去
#   入: 1.0000
# State: ，去入
#   职: 1.0000
# State: 去入职
#   新: 1.0000
# State: 入职新
#   员: 1.0000
# State: 职新员
#   工: 1.0000
# State: 新员工
#   中: 0.2500
#   在: 0.2500
#   喝: 0.2500
#   是: 0.2500
# State: 员工中
#   寻: 1.0000
# State: 工中寻
#   找: 1.0000
# State: 中寻找
#   合: 1.0000
# State: 寻找合
#   适: 1.0000
# State: 找合适
#   的: 1.0000
# State: 合适的
#   人: 1.0000
# State: 适的人
#   。: 1.0000
# State: 的人。
#   专: 1.0000
# State: 人。专
#   家: 1.0000
# State: 。专家
#   先: 1.0000
# State: 专家先
#   把: 1.0000
# State: 家先把
#   一: 1.0000
# State: 先把一
#   些: 1.0000
# State: 把一些
#   题: 1.0000
# State: 一些题
#   目: 1.0000
# State: 些题目
#   出: 1.0000
# State: 题目出
#   在: 1.0000
# State: 目出在
#   网: 1.0000
# State: 出在网
#   上: 1.0000
# State: 在网上
#   ，: 1.0000
# State: 网上，
#   有: 1.0000
# State: 上，有
#   人: 1.0000
# State: ，有人
#   回: 0.5000
#   选: 0.5000
# State: 有人回
#   帖: 1.0000
# State: 人回帖
#   ，: 1.0000
# State: 回帖，
#   专: 1.0000
# State: 帖，专
#   家: 1.0000
# State: ，专家
#   就: 0.5000
#   签: 0.5000
# State: 专家就
#   去: 1.0000
# State: 家就去
#   找: 1.0000
# State: 就去找
#   他: 1.0000
# State: 去找他
#   喝: 1.0000
# State: 找他喝
#   咖: 1.0000
# State: 他喝咖
#   啡: 1.0000
# State: 喝咖啡
#   沟: 0.2000
#   时: 0.2000
#   是: 0.2000
#   ”: 0.2000
#   呢: 0.2000
# State: 咖啡沟
#   通: 1.0000
# State: 啡沟通
#   ，: 1.0000
# State: 沟通，
#   判: 1.0000
# State: 通，判
#   断: 1.0000
# State: ，判断
#   这: 1.0000
# State: 判断这
#   个: 1.0000
# State: 断这个
#   人: 1.0000
# State: 这个人
#   是: 1.0000
# State: 个人是
#   否: 1.0000
# State: 人是否
#   明: 1.0000
# State: 是否明
#   白: 1.0000
# State: 否明白
#   了: 1.0000
# State: 明白了
#   题: 1.0000
# State: 白了题
#   目: 1.0000
# State: 了题目
#   ，: 1.0000
# State: 题目，
#   是: 1.0000
# State: 目，是
#   否: 1.0000
# State: ，是否
#   有: 1.0000
# State: 是否有
#   破: 1.0000
# State: 否有破
#   题: 1.0000
# State: 有破题
#   的: 1.0000
# State: 破题的
#   能: 1.0000
# State: 题的能
#   力: 1.0000
# State: 的能力
#   ，: 1.0000
# State: 能力，
#   他: 0.5000
#   绕: 0.5000
# State: 力，他
#   适: 1.0000
# State: ，他适
#   合: 1.0000
# State: 他适合
#   到: 1.0000
# State: 适合到
#   哪: 1.0000
# State: 合到哪
#   个: 1.0000
# State: 到哪个
#   部: 1.0000
# State: 哪个部
#   门: 1.0000
# State: 个部门
#   工: 1.0000
# State: 部门工
#   作: 1.0000
# State: 门工作
#   、: 1.0000
# State: 工作、
#   定: 1.0000
# State: 作、定
#   多: 1.0000
# State: 、定多
#   少: 1.0000
# State: 定多少
#   级: 1.0000
# State: 多少级
#   ，: 1.0000
# State: 少级，
#   专: 1.0000
# State: 级，专
#   家: 1.0000
# State: 专家签
#   字: 1.0000
# State: 家签字
#   就: 1.0000
# State: 签字就
#   行: 0.5000
#   确: 0.5000
# State: 字就行
#   。: 1.0000
# State: 就行。
#   新: 1.0000
# State: 行。新
#   员: 1.0000
# State: 。新员
#   工: 1.0000
# State: 员工在
#   入: 1.0000
# State: 工在入
#   职: 1.0000
# State: 在入职
#   时: 1.0000
# State: 入职时
#   就: 1.0000
# State: 职时就
#   可: 1.0000
# State: 时就可
#   以: 1.0000
# State: 就可以
#   有: 1.0000
# State: 可以有
#   差: 0.5000
#   一: 0.5000
# State: 以有差
#   异: 1.0000
# State: 有差异
#   化: 1.0000
# State: 差异化
#   ，: 1.0000
# State: 异化，
#   为: 1.0000
# State: 化，为
#   什: 1.0000
# State: ，为什
#   么: 1.0000
# State: 为什么
#   同: 0.3333
#   大: 0.3333
#   不: 0.3333
# State: 什么同
#   班: 1.0000
# State: 么同班
#   同: 1.0000
# State: 同班同
#   学: 1.0000
# State: 班同学
#   一: 1.0000
# State: 同学一
#   定: 1.0000
# State: 学一定
#   要: 1.0000
# State: 一定要
#   整: 0.3333
#   懂: 0.3333
#   去: 0.3333
# State: 定要整
#   齐: 1.0000
# State: 要整齐
#   划: 1.0000
# State: 整齐划
#   一: 1.0000
# State: 齐划一
#   前: 1.0000
# State: 划一前
#   进: 1.0000
# State: 一前进
#   呢: 1.0000
# State: 前进呢
#   ？: 1.0000
# State: 进呢？
#   我: 1.0000
# State: 呢？我
#   们: 0.5000
#   认: 0.5000
# State: ？我们
#   不: 1.0000
# State: 不要担
#   心: 1.0000
# State: 要担心
#   定: 1.0000
# State: 担心定
#   错: 1.0000
# State: 心定错
#   级: 1.0000
# State: 定错级
#   ，: 1.0000
# State: 错级，
#   即: 1.0000
# State: 级，即
#   使: 1.0000
# State: ，即使
#   定: 1.0000
# State: 即使定
#   错: 1.0000
# State: 使定错
#   也: 1.0000
# State: 定错也
#   是: 1.0000
# State: 错也是
#   一: 1.0000
# State: 也是一
#   个: 1.0000
# State: 是一个
#   短: 0.3333
#   很: 0.3333
#   沟: 0.3333
# State: 一个短
#   时: 1.0000
# State: 个短时
#   间: 1.0000
# State: 短时间
#   的: 1.0000
# State: 时间的
#   问: 0.5000
#   高: 0.5000
# State: 间的问
#   题: 1.0000
# State: 的问题
#   。: 1.0000
# State: 问题。
#   如: 1.0000
# State: 题。如
#   果: 1.0000
# State: 。如果
#   他: 0.3333
#   在: 0.3333
#   没: 0.3333
# State: 果他确
#   实: 1.0000
# State: 他确实
#   没: 0.5000
#   有: 0.5000
# State: 确实没
#   本: 1.0000
# State: 实没本
#   事: 1.0000
# State: 没本事
#   ，: 1.0000
# State: 本事，
#   过: 0.5000
#   就: 0.5000
# State: 事，过
#   一: 1.0000
# State: ，过一
#   段: 1.0000
# State: 过一段
#   时: 1.0000
# State: 一段时
#   间: 1.0000
# State: 段时间
#   就: 1.0000
# State: 时间就
#   会: 1.0000
# State: 间就会
#   被: 1.0000
# State: 就会被
#   自: 1.0000
# State: 会被自
#   然: 1.0000
# State: 被自然
#   淘: 1.0000
# State: 自然淘
#   汰: 1.0000
# State: 然淘汰
#   ，: 1.0000
# State: 淘汰，
#   也: 1.0000
# State: 汰，也
#   只: 1.0000
# State: ，也只
#   拿: 1.0000
# State: 也只拿
#   错: 1.0000
# State: 只拿错
#   了: 1.0000
# State: 拿错了
#   短: 1.0000
# State: 错了短
#   时: 1.0000
# State: 了短时
#   间: 1.0000
# State: 间的高
#   工: 1.0000
# State: 的高工
#   资: 1.0000
# State: 高工资
#   ；: 1.0000
# State: 工资；
#   如: 1.0000
# State: 资；如
#   果: 1.0000
# State: ；如果
#   他: 1.0000
# State: 确实有
#   本: 1.0000
# State: 实有本
#   事: 1.0000
# State: 有本事
#   ，: 1.0000
# State: 事，就
#   还: 1.0000
# State: ，就还
#   会: 1.0000
# State: 就还会
#   往: 1.0000
# State: 还会往
#   上: 1.0000
# State: 会往上
#   升: 1.0000
# State: 往上升
#   ，: 1.0000
# State: 上升，
#   很: 0.5000
#   最: 0.5000
# State: 升，很
#   快: 1.0000
# State: ，很快
#   就: 1.0000
# State: 很快就
#   能: 1.0000
# State: 快就能
#   超: 1.0000
# State: 就能超
#   过: 1.0000
# State: 能超过
#   你: 1.0000
# State: 超过你
#   的: 1.0000
# State: 过你的
#   标: 1.0000
# State: 你的标
#   准: 1.0000
# State: 的标准
#   线: 1.0000
# State: 标准线
#   。: 1.0000
# State: 准线。
#   如: 1.0000
# State: 线。如
#   果: 1.0000
# State: 如果在
#   定: 1.0000
# State: 果在定
#   级: 1.0000
# State: 在定级
#   上: 1.0000
# State: 定级上
#   有: 1.0000
# State: 级上有
#   担: 1.0000
# State: 上有担
#   心: 1.0000
# State: 有担心
#   ，: 1.0000
# State: 担心，
#   可: 1.0000
# State: 心，可
#   以: 1.0000
# State: ，可以
#   有: 0.5000
#   适: 0.5000
# State: 以有一
#   个: 1.0000
# State: 有一个
#   主: 1.0000
# State: 一个主
#   谈: 1.0000
# State: 个主谈
#   人: 1.0000
# State: 主谈人
#   和: 1.0000
# State: 谈人和
#   一: 1.0000
# State: 人和一
#   个: 1.0000
# State: 和一个
#   复: 1.0000
# State: 一个复
#   核: 1.0000
# State: 个复核
#   人: 1.0000
# State: 复核人
#   ，: 1.0000
# State: 核人，
#   两: 1.0000
# State: 人，两
#   人: 1.0000
# State: ，两人
#   签: 1.0000
# State: 两人签
#   字: 1.0000
# State: 人签字
#   就: 1.0000
# State: 字就确
#   定: 1.0000
# State: 就确定
#   了: 1.0000
# State: 确定了
#   ，: 1.0000
# State: 定了，
#   不: 1.0000
# State: 了，不
#   需: 1.0000
# State: ，不需
#   要: 1.0000
# State: 不需要
#   强: 1.0000
# State: 需要强
#   调: 1.0000
# State: 要强调
#   严: 1.0000
# State: 强调严
#   丝: 1.0000
# State: 调严丝
#   合: 1.0000
# State: 严丝合
#   缝: 1.0000
# State: 丝合缝
#   1: 1.0000
# State: 合缝1
#   0: 1.0000
# State: 缝10
#   0: 1.0000
# State: 100
#   %: 1.0000
# State: 00%
#   准: 1.0000
# State: 0%准
#   确: 1.0000
# State: %准确
#   ，: 1.0000
# State: 准确，
#   可: 1.0000
# State: 确，可
#   以: 1.0000
# State: 适当模
#   糊: 1.0000
# State: 当模糊
#   一: 1.0000
# State: 模糊一
#   些: 1.0000
# State: 糊一些
#   。: 1.0000
# State: 一些。
#   其: 1.0000
# State: 些。其
#   实: 1.0000
# State: 。其实
#   ，: 1.0000
# State: 其实，
#   集: 1.0000
# State: 实，集
#   体: 1.0000
# State: ，集体
#   评: 1.0000
# State: 集体评
#   议: 1.0000
# State: 体评议
#   往: 1.0000
# State: 评议往
#   往: 1.0000
# State: 议往往
#   会: 1.0000
# State: 往往会
#   埋: 1.0000
# State: 往会埋
#   没: 1.0000
# State: 会埋没
#   人: 1.0000
# State: 埋没人
#   才: 1.0000
# State: 没人才
#   。: 1.0000
# State: 人才。
#   “: 1.0000
# State: 才。“
#   歪: 1.0000
# State: 。“歪
#   瓜: 1.0000
# State: “歪瓜
#   裂: 1.0000
# State: 歪瓜裂
#   枣: 1.0000
# State: 瓜裂枣
#   ”: 1.0000
# State: 裂枣”
#   很: 1.0000
# State: 枣”很
#   多: 1.0000
# State: ”很多
#   ，: 1.0000
# State: 很多，
#   我: 0.5000
#   当: 0.5000
# State: 多，我
#   们: 1.0000
# State: 们的专
#   家: 1.0000
# State: 的专家
#   要: 0.3333
#   合: 0.3333
#   走: 0.3333
# State: 专家要
#   识: 0.5000
#   用: 0.5000
# State: 家要识
#   别: 1.0000
# State: 要识别
#   他: 1.0000
# State: 识别他
#   特: 1.0000
# State: 别他特
#   殊: 1.0000
# State: 他特殊
#   能: 1.0000
# State: 特殊能
#   力: 1.0000
# State: 殊能力
#   的: 1.0000
# State: 能力的
#   一: 1.0000
# State: 力的一
#   面: 1.0000
# State: 的一面
#   就: 1.0000
# State: 一面就
#   行: 1.0000
# State: 面就行
#   ，: 1.0000
# State: 就行，
#   也: 0.5000
#   大: 0.5000
# State: 行，也
#   不: 1.0000
# State: 也不用
#   全: 1.0000
# State: 不用全
#   面: 1.0000
# State: 用全面
#   评: 1.0000
# State: 全面评
#   价: 1.0000
# State: 面评价
#   一: 1.0000
# State: 评价一
#   个: 1.0000
# State: 价一个
#   人: 1.0000
# State: 一个人
#   ，: 1.0000
# State: 个人，
#   “: 1.0000
# State: 人，“
#   不: 1.0000
# State: ，“不
#   拘: 1.0000
# State: “不拘
#   一: 1.0000
# State: 一格降
#   人: 1.0000
# State: 格降人
#   才: 1.0000
# State: 降人才
#   ”: 1.0000
# State: 人才”
#   。: 1.0000
# State: 才”。
#   比: 1.0000
# State: ”。比
#   如: 1.0000
# State: 如，清
#   华: 1.0000
# State: ，清华
#   大: 1.0000
# State: 清华大
#   学: 1.0000
# State: 华大学
#   数: 0.5000
#   ，: 0.5000
# State: 大学数
#   学: 1.0000
# State: 学数学
#   系: 1.0000
# State: 数学系
#   主: 1.0000
# State: 学系主
#   任: 1.0000
# State: 系主任
#   熊: 1.0000
# State: 主任熊
#   庆: 1.0000
# State: 任熊庆
#   来: 1.0000
# State: 熊庆来
#   让: 1.0000
# State: 庆来让
#   只: 1.0000
# State: 来让只
#   有: 1.0000
# State: 让只有
#   初: 1.0000
# State: 只有初
#   中: 1.0000
# State: 有初中
#   学: 1.0000
# State: 初中学
#   历: 1.0000
# State: 中学历
#   的: 1.0000
# State: 学历的
#   华: 1.0000
# State: 历的华
#   罗: 1.0000
# State: 的华罗
#   庚: 1.0000
# State: 华罗庚
#   破: 0.5000
#   高: 0.5000
# State: 罗庚破
#   格: 1.0000
# State: 庚破格
#   进: 1.0000
# State: 破格进
#   入: 1.0000
# State: 格进入
#   清: 1.0000
# State: 进入清
#   华: 1.0000
# State: 入清华
#   大: 1.0000
# State: 大学，
#   开: 1.0000
# State: 学，开
#   启: 1.0000
# State: ，开启
#   了: 1.0000
# State: 开启了
#   华: 1.0000
# State: 启了华
#   罗: 1.0000
# State: 了华罗
#   庚: 1.0000
# State: 罗庚高
#   水: 1.0000
# State: 庚高水
#   平: 1.0000
# State: 高水平
#   数: 1.0000
# State: 水平数
#   学: 1.0000
# State: 平数学
#   的: 1.0000
# State: 数学的
#   研: 1.0000
# State: 学的研
#   究: 1.0000
# State: 的研究
#   生: 1.0000
# State: 研究生
#   涯: 1.0000
# State: 究生涯
#   ；: 1.0000
# State: 生涯；
#   罗: 1.0000
# State: 涯；罗
#   家: 1.0000
# State: ；罗家
#   伦: 1.0000
# State: 罗家伦
#   当: 1.0000
# State: 家伦当
#   清: 1.0000
# State: 伦当清
#   华: 1.0000
# State: 当清华
#   校: 1.0000
# State: 清华校
#   长: 1.0000
# State: 华校长
#   时: 1.0000
# State: 校长时
#   ，: 1.0000
# State: 长时，
#   录: 1.0000
# State: 时，录
#   取: 1.0000
# State: ，录取
#   了: 1.0000
# State: 录取了
#   数: 1.0000
# State: 取了数
#   学: 1.0000
# State: 了数学
#   成: 1.0000
# State: 数学成
#   绩: 1.0000
# State: 学成绩
#   只: 1.0000
# State: 成绩只
#   有: 1.0000
# State: 绩只有
#   1: 1.0000
# State: 只有1
#   5: 1.0000
# State: 有15
#   分: 0.5000
#   0: 0.5000
# State: 15分
#   的: 1.0000
# State: 5分的
#   钱: 1.0000
# State: 分的钱
#   钟: 1.0000
# State: 的钱钟
#   书: 1.0000
# State: 钱钟书
#   ，: 1.0000
# State: 钟书，
#   成: 1.0000
# State: 书，成
#   就: 1.0000
# State: ，成就
#   了: 1.0000
# State: 成就了
#   一: 1.0000
# State: 就了一
#   位: 1.0000
# State: 了一位
#   文: 1.0000
# State: 一位文
#   学: 1.0000
# State: 位文学
#   大: 1.0000
# State: 文学大
#   师: 1.0000
# State: 学大师
#   。: 1.0000
# State: 大师。
#   初: 1.0000
# State: 师。初
#   始: 1.0000
# State: 。初始
#   职: 1.0000
# State: 初始职
#   级: 1.0000
# State: 始职级
#   ，: 1.0000
# State: 职级，
#   在: 1.0000
# State: 级，在
#   校: 1.0000
# State: ，在校
#   园: 1.0000
# State: 在校园
#   招: 1.0000
# State: 校园招
#   聘: 1.0000
# State: 园招聘
#   时: 1.0000
# State: 聘时可
#   以: 1.0000
# State: 时可以
#   定: 1.0000
# State: 可以定
#   一: 1.0000
# State: 以定一
#   次: 1.0000
# State: 定一次
#   ，: 1.0000
# State: 一次，
#   在: 0.5000
#   我: 0.5000
# State: 次，在
#   与: 1.0000
# State: ，在与
#   优: 1.0000
# State: 在与优
#   秀: 1.0000
# State: 与优秀
#   新: 1.0000
# State: 优秀新
#   员: 1.0000
# State: 秀新员
#   工: 1.0000
# State: 员工喝
#   咖: 1.0000
# State: 工喝咖
#   啡: 1.0000
# State: 咖啡时
#   也: 1.0000
# State: 啡时也
#   可: 1.0000
# State: 时也可
#   以: 1.0000
# State: 也可以
#   再: 1.0000
# State: 可以再
#   定: 1.0000
# State: 以再定
#   一: 1.0000
# State: 再定一
#   次: 1.0000
# State: 次，我
#   们: 1.0000
# State: 我们直
#   接: 1.0000
# State: 们直接
#   授: 1.0000
# State: 直接授
#   权: 1.0000
# State: 接授权
#   这: 1.0000
# State: 授权这
#   批: 1.0000
# State: 权这批
#   专: 1.0000
# State: 这批专
#   家: 1.0000
# State: 批专家
#   。: 1.0000
# State: 专家。
#   三: 1.0000
# State: 家。三
#   、: 1.0000
# State: 。三、
#   全: 1.0000
# State: 三、全
#   才: 1.0000
# State: 、全才
#   是: 1.0000
# State: 全才是
#   从: 1.0000
# State: 才是从
#   专: 1.0000
# State: 是从专
#   才: 1.0000
# State: 从专才
#   中: 1.0000
# State: 专才中
#   产: 0.5000
#   成: 0.5000
# State: 才中产
#   生: 1.0000
# State: 中产生
#   的: 1.0000
# State: 产生的
#   ，: 0.3333
#   ？: 0.3333
#   是: 0.3333
# State: 生的，
#   领: 1.0000
# State: 的，领
#   袖: 1.0000
# State: ，领袖
#   是: 1.0000
# State: 领袖是
#   自: 1.0000
# State: 袖是自
#   然: 1.0000
# State: 是自然
#   成: 1.0000
# State: 自然成
#   长: 1.0000
# State: 然成长
#   起: 1.0000
# State: 成长起
#   来: 1.0000
# State: 长起来
#   的: 0.7500
#   ，: 0.2500
# State: 起来的
#   。: 0.6667
#   ，: 0.3333
# State: 来的。
#   第: 0.5000
#   他: 0.5000
# State: 的。第
#   一: 0.5000
#   二: 0.5000
# State: 。第一
#   ，: 1.0000
# State: 第一，
#   全: 0.5000
#   高: 0.5000
# State: 一，全
#   才: 1.0000
# State: ，全才
#   首: 0.5000
#   是: 0.5000
# State: 全才首
#   先: 1.0000
# State: 才首先
#   一: 1.0000
# State: 首先一
#   定: 1.0000
# State: 先一定
#   是: 1.0000
# State: 一定是
#   专: 1.0000
# State: 定是专
#   才: 1.0000
# State: 是专才
#   ，: 1.0000
# State: 专才，
#   全: 0.5000
#   就: 0.5000
# State: 才，全
#   才: 1.0000
# State: 才中成
#   长: 1.0000
# State: 中成长
#   起: 1.0000
# State: 的。他
#   在: 1.0000
# State: 。他在
#   某: 1.0000
# State: 他在某
#   一: 1.0000
# State: 在某一
#   项: 0.5000
#   件: 0.5000
# State: 某一项
#   钻: 1.0000
# State: 一项钻
#   研: 1.0000
# State: 项钻研
#   得: 1.0000
# State: 钻研得
#   很: 1.0000
# State: 研得很
#   透: 1.0000
# State: 得很透
#   ，: 1.0000
# State: 很透，
#   在: 1.0000
# State: 透，在
#   其: 1.0000
# State: ，在其
#   他: 1.0000
# State: 在其他
#   项: 1.0000
# State: 其他项
#   就: 1.0000
# State: 他项就
#   能: 1.0000
# State: 项就能
#   理: 1.0000
# State: 就能理
#   解: 1.0000
# State: 能理解
#   。: 1.0000
# State: 理解。
#   如: 1.0000
# State: 解。如
#   果: 1.0000
# State: 如果没
#   有: 1.0000
# State: 果没有
#   专: 1.0000
# State: 没有专
#   才: 1.0000
# State: 有专才
#   ，: 0.5000
#   的: 0.5000
# State: 才，就
#   不: 1.0000
# State: ，就不
#   可: 1.0000
# State: 就不可
#   能: 1.0000
# State: 不可能
#   成: 1.0000
# State: 可能成
#   为: 1.0000
# State: 能成为
#   全: 1.0000
# State: 成为全
#   才: 1.0000
# State: 为全才
#   ，: 1.0000
# State: 全才，
#   没: 1.0000
# State: 才，没
#   有: 1.0000
# State: 专才的
#   “: 1.0000
# State: 才的“
#   全: 1.0000
# State: 的“全
#   才: 1.0000
# State: “全才
#   ”: 1.0000
# State: 全才”
#   也: 1.0000
# State: 才”也
#   许: 1.0000
# State: ”也许
#   没: 1.0000
# State: 也许没
#   有: 1.0000
# State: 许没有
#   突: 1.0000
# State: 没有突
#   破: 1.0000
# State: 有突破
#   能: 1.0000
# State: 突破能
#   力: 1.0000
# State: 破能力
#   ，: 1.0000
# State: 力，绕
#   着: 1.0000
# State: ，绕着
#   城: 1.0000
# State: 绕着城
#   墙: 1.0000
# State: 着城墙
#   转: 1.0000
# State: 城墙转
#   ，: 1.0000
# State: 墙转，
#   找: 1.0000
# State: 转，找
#   不: 1.0000
# State: ，找不
#   到: 1.0000
# State: 找不到
#   放: 1.0000
# State: 不到放
#   “: 1.0000
# State: 到放“
#   炸: 1.0000
# State: 放“炸
#   药: 1.0000
# State: “炸药
#   包: 1.0000
# State: 炸药包
#   ”: 1.0000
# State: 药包”
#   的: 1.0000
# State: 包”的
#   地: 1.0000
# State: ”的地
#   方: 1.0000
# State: 的地方
#   。: 1.0000
# State: 地方。
#   系: 1.0000
# State: 方。系
#   统: 1.0000
# State: 。系统
#   性: 1.0000
# State: 系统性
#   的: 1.0000
# State: 统性的
#   、: 1.0000
# State: 性的、
#   阐: 1.0000
# State: 的、阐
#   述: 1.0000
# State: 、阐述
#   性: 1.0000
# State: 阐述性
#   的: 1.0000
# State: 述性的
#   和: 1.0000
# State: 性的和
#   构: 1.0000
# State: 的和构
#   建: 1.0000
# State: 和构建
#   性: 1.0000
# State: 构建性
#   的: 1.0000
# State: 建性的
#   专: 1.0000
# State: 性的专
#   家: 1.0000
# State: 专家合
#   起: 1.0000
# State: 家合起
#   来: 1.0000
# State: 合起来
#   也: 1.0000
# State: 起来也
#   不: 1.0000
# State: 来也不
#   行: 1.0000
# State: 也不行
#   ，: 1.0000
# State: 不行，
#   就: 1.0000
# State: 行，就
#   如: 1.0000
# State: ，就如
#   皮: 0.5000
#   “: 0.5000
# State: 就如皮
#   蛋: 1.0000
# State: 如皮蛋
#   粥: 1.0000
# State: 皮蛋粥
#   一: 1.0000
# State: 蛋粥一
#   样: 1.0000
# State: 粥一样
#   ，: 1.0000
# State: 一样，
#   皮: 1.0000
# State: 样，皮
#   蛋: 1.0000
# State: ，皮蛋
#   还: 1.0000
# State: 皮蛋还
#   是: 1.0000
# State: 蛋还是
#   皮: 1.0000
# State: 还是皮
#   蛋: 1.0000
# State: 是皮蛋
#   ，: 1.0000
# State: 皮蛋，
#   粥: 1.0000
# State: 蛋，粥
#   还: 1.0000
# State: ，粥还
#   是: 1.0000
# State: 粥还是
#   粥: 1.0000
# State: 还是粥
#   ，: 1.0000
# State: 是粥，
#   并: 1.0000
# State: 粥，并
#   没: 1.0000
# State: ，并没
#   有: 1.0000
# State: 并没有
#   发: 1.0000
# State: 没有发
#   生: 1.0000
# State: 有发生
#   物: 1.0000
# State: 发生物
#   理: 1.0000
# State: 生物理
#   和: 1.0000
# State: 物理和
#   化: 1.0000
# State: 理和化
#   学: 1.0000
# State: 和化学
#   性: 1.0000
# State: 化学性
#   的: 1.0000
# State: 学性的
#   转: 1.0000
# State: 性的转
#   变: 1.0000
# State: 的转变
#   。: 1.0000
# State: 转变。
#   领: 1.0000
# State: 变。领
#   袖: 1.0000
# State: 。领袖
#   是: 1.0000
# State: 来的，
#   不: 1.0000
# State: 的，不
#   是: 1.0000
# State: 不是我
#   们: 1.0000
# State: 是我们
#   去: 0.5000
#   要: 0.5000
# State: 我们去
#   找: 1.0000
# State: 们去找
#   。: 1.0000
# State: 去找。
#   大: 1.0000
# State: 找。大
#   家: 1.0000
# State: 。大家
#   看: 1.0000
# State: 大家看
#   到: 1.0000
# State: 家看到
#   ，: 1.0000
# State: 看到，
#   为: 1.0000
# State: 到，为
#   什: 1.0000
# State: 什么大
#   领: 1.0000
# State: 么大领
#   袖: 1.0000
# State: 大领袖
#   、: 1.0000
# State: 领袖、
#   大: 1.0000
# State: 袖、大
#   统: 1.0000
# State: 、大统
#   帅: 1.0000
# State: 大统帅
#   绝: 1.0000
# State: 统帅绝
#   大: 1.0000
# State: 帅绝大
#   多: 1.0000
# State: 绝大多
#   数: 1.0000
# State: 大多数
#   都: 1.0000
# State: 多数都
#   是: 1.0000
# State: 数都是
#   小: 1.0000
# State: 都是小
#   镇: 1.0000
# State: 是小镇
#   上: 1.0000
# State: 小镇上
#   产: 1.0000
# State: 镇上产
#   生: 1.0000
# State: 上产生
#   的: 1.0000
# State: 生的？
#   因: 1.0000
# State: 的？因
#   为: 1.0000
# State: ？因为
#   大: 1.0000
# State: 因为大
#   都: 1.0000
# State: 为大都
#   市: 1.0000
# State: 大都市
#   很: 1.0000
# State: 都市很
#   重: 1.0000
# State: 市很重
#   视: 1.0000
# State: 很重视
#   规: 1.0000
# State: 重视规
#   矩: 1.0000
# State: 视规矩
#   ，: 1.0000
# State: 规矩，
#   约: 1.0000
# State: 矩，约
#   束: 1.0000
# State: ，约束
#   很: 1.0000
# State: 约束很
#   多: 1.0000
# State: 束很多
#   ，: 1.0000
# State: 多，当
#   然: 1.0000
# State: ，当然
#   不: 1.0000
# State: 当然不
#   仅: 1.0000
# State: 然不仅
#   仅: 1.0000
# State: 不仅仅
#   是: 1.0000
# State: 仅仅是
#   父: 1.0000
# State: 仅是父
#   母: 1.0000
# State: 是父母
#   、: 1.0000
# State: 父母、
#   社: 1.0000
# State: 母、社
#   会: 1.0000
# State: 、社会
#   、: 1.0000
# State: 社会、
#   环: 1.0000
# State: 会、环
#   境: 1.0000
# State: 、环境
#   、: 1.0000
# State: 环境、
#   同: 1.0000
# State: 境、同
#   时: 1.0000
# State: 、同时
#   代: 1.0000
# State: 同时代
#   的: 1.0000
# State: 时代的
#   小: 1.0000
# State: 代的小
#   朋: 1.0000
# State: 的小朋
#   友: 1.0000
# State: 小朋友
#   ，: 1.0000
# State: 朋友，
#   因: 1.0000
# State: 友，因
#   此: 1.0000
# State: ，因此
#   它: 1.0000
# State: 因此它
#   们: 1.0000
# State: 此它们
#   大: 1.0000
# State: 它们大
#   量: 1.0000
# State: 们大量
#   产: 1.0000
# State: 大量产
#   生: 1.0000
# State: 量产生
#   的: 1.0000
# State: 生的是
#   工: 1.0000
# State: 的是工
#   程: 1.0000
# State: 是工程
#   师: 1.0000
# State: 工程师
#   、: 1.0000
# State: 程师、
#   艺: 1.0000
# State: 师、艺
#   术: 1.0000
# State: 、艺术
#   家: 1.0000
# State: 艺术家
#   ；: 1.0000
# State: 术家；
#   小: 1.0000
# State: 家；小
#   镇: 1.0000
# State: ；小镇
#   没: 1.0000
# State: 小镇没
#   有: 1.0000
# State: 镇没有
#   那: 1.0000
# State: 没有那
#   么: 1.0000
# State: 有那么
#   多: 1.0000
# State: 那么多
#   条: 1.0000
# State: 么多条
#   条: 1.0000
# State: 多条条
#   框: 1.0000
# State: 条条框
#   框: 1.0000
# State: 条框框
#   ，: 1.0000
# State: 框框，
#   小: 1.0000
# State: 框，小
#   孩: 1.0000
# State: ，小孩
#   也: 1.0000
# State: 小孩也
#   不: 1.0000
# State: 孩也不
#   懂: 1.0000
# State: 也不懂
#   得: 1.0000
# State: 不懂得
#   太: 1.0000
# State: 懂得太
#   多: 1.0000
# State: 得太多
#   的: 1.0000
# State: 太多的
#   世: 1.0000
# State: 多的世
#   界: 1.0000
# State: 的世界
#   ，: 1.0000
# State: 界，他
#   们: 1.0000
# State: ，他们
#   在: 1.0000
# State: 他们在
#   某: 1.0000
# State: 们在某
#   一: 1.0000
# State: 某一件
#   事: 1.0000
# State: 一件事
#   上: 1.0000
# State: 件事上
#   就: 1.0000
# State: 事上就
#   容: 1.0000
# State: 上就容
#   易: 1.0000
# State: 就容易
#   抓: 0.5000
#   成: 0.5000
# State: 容易抓
#   住: 1.0000
# State: 易抓住
#   主: 1.0000
# State: 抓住主
#   要: 1.0000
# State: 住主要
#   矛: 1.0000
# State: 主要矛
#   盾: 1.0000
# State: 要矛盾
#   和: 1.0000
# State: 矛盾和
#   矛: 1.0000
# State: 盾和矛
#   盾: 1.0000
# State: 和矛盾
#   的: 1.0000
# State: 矛盾的
#   主: 1.0000
# State: 盾的主
#   要: 1.0000
# State: 的主要
#   方: 1.0000
# State: 主要方
#   面: 1.0000
# State: 要方面
#   ，: 1.0000
# State: 面，就
#   容: 1.0000
# State: ，就容
#   易: 1.0000
# State: 容易成
#   长: 1.0000
# State: 易成长
#   起: 1.0000
# State: 起来，
#   产: 1.0000
# State: 来，产
#   生: 1.0000
# State: ，产生
#   历: 1.0000
# State: 产生历
#   史: 1.0000
# State: 生历史
#   贡: 1.0000
# State: 历史贡
#   献: 1.0000
# State: 史贡献
#   。: 1.0000
# State: 贡献。
#   小: 1.0000
# State: 献。小
#   孩: 1.0000
# State: 。小孩
#   走: 1.0000
# State: 小孩走
#   路: 1.0000
# State: 孩走路
#   喜: 1.0000
# State: 走路喜
#   欢: 1.0000
# State: 路喜欢
#   踩: 1.0000
# State: 喜欢踩
#   小: 1.0000
# State: 欢踩小
#   水: 1.0000
# State: 踩小水
#   坑: 1.0000
# State: 小水坑
#   ，: 1.0000
# State: 水坑，
#   只: 1.0000
# State: 坑，只
#   有: 1.0000
# State: ，只有
#   他: 1.0000
# State: 只有他
#   自: 1.0000
# State: 有他自
#   己: 1.0000
# State: 他自己
#   摔: 1.0000
# State: 自己摔
#   两: 1.0000
# State: 己摔两
#   次: 1.0000
# State: 摔两次
#   ，: 1.0000
# State: 两次，
#   才: 1.0000
# State: 次，才
#   知: 1.0000
# State: ，才知
#   道: 1.0000
# State: 才知道
#   水: 1.0000
# State: 知道水
#   坑: 1.0000
# State: 道水坑
#   不: 1.0000
# State: 水坑不
#   能: 1.0000
# State: 坑不能
#   踩: 1.0000
# State: 不能踩
#   ，: 1.0000
# State: 能踩，
#   才: 1.0000
# State: 踩，才
#   有: 1.0000
# State: ，才有
#   自: 1.0000
# State: 才有自
#   主: 1.0000
# State: 有自主
#   决: 1.0000
# State: 自主决
#   策: 1.0000
# State: 主决策
#   能: 1.0000
# State: 决策能
#   力: 1.0000
# State: 策能力
#   。: 1.0000
# State: 能力。
#   所: 1.0000
# State: 力。所
#   以: 1.0000
# State: 我们强
#   调: 1.0000
# State: 们强调
#   要: 1.0000
# State: 强调要
#   有: 1.0000
# State: 调要有
#   成: 1.0000
# State: 要有成
#   功: 1.0000
# State: 有成功
#   的: 0.5000
#   过: 0.5000
# State: 成功的
#   实: 1.0000
# State: 功的实
#   践: 1.0000
# State: 实践经
#   验: 1.0000
# State: 践经验
#   ，: 1.0000
# State: 经验，
#   做: 1.0000
# State: 验，做
#   一: 1.0000
# State: ，做一
#   个: 1.0000
# State: 做一个
#   小: 1.0000
# State: 一个小
#   项: 1.0000
# State: 个小项
#   目: 1.0000
# State: 小项目
#   成: 1.0000
# State: 项目成
#   功: 1.0000
# State: 目成功
#   ，: 1.0000
# State: 成功，
#   他: 1.0000
# State: 功，他
#   就: 1.0000
# State: 他就知
#   道: 1.0000
# State: 就知道
#   什: 0.5000
#   跨: 0.5000
# State: 知道什
#   么: 1.0000
# State: 道什么
#   叫: 1.0000
# State: 什么叫
#   决: 1.0000
# State: 么叫决
#   策: 1.0000
# State: 叫决策
#   ；: 1.0000
# State: 决策；
#   如: 1.0000
# State: 策；如
#   果: 1.0000
# State: 果他一
#   个: 1.0000
# State: 他一个
#   事: 1.0000
# State: 一个事
#   情: 1.0000
# State: 个事情
#   都: 1.0000
# State: 事情都
#   没: 1.0000
# State: 情都没
#   有: 1.0000
# State: 都没有
#   成: 1.0000
# State: 没有成
#   功: 1.0000
# State: 成功过
#   ，: 1.0000
# State: 功过，
#   他: 1.0000
# State: 过，他
#   当: 1.0000
# State: ，他当
#   高: 1.0000
# State: 他当高
#   级: 1.0000
# State: 当高级
#   干: 1.0000
# State: 高级干
#   部: 1.0000
# State: 级干部
#   时: 1.0000
# State: 干部时
#   的: 1.0000
# State: 部时的
#   决: 1.0000
# State: 时的决
#   策: 1.0000
# State: 的决策
#   就: 1.0000
# State: 决策就
#   是: 1.0000
# State: 策就是
#   胡: 1.0000
# State: 就是胡
#   来: 1.0000
# State: 是胡来
#   。: 1.0000
# State: 胡来。
#   我: 1.0000
# State: 来。我
#   们: 1.0000
# State: 我们在
#   选: 1.0000
# State: 们在选
#   择: 1.0000
# State: 在选择
#   干: 1.0000
# State: 选择干
#   部: 1.0000
# State: 择干部
#   的: 1.0000
# State: 干部的
#   时: 1.0000
# State: 部的时
#   候: 1.0000
# State: 候，贯
#   彻: 1.0000
# State: ，贯彻
#   没: 1.0000
# State: 贯彻没
#   贡: 1.0000
# State: 彻没贡
#   献: 1.0000
# State: 没贡献
#   不: 1.0000
# State: 贡献不
#   考: 1.0000
# State: 献不考
#   核: 1.0000
# State: 不考核
#   ，: 1.0000
# State: 考核，
#   节: 1.0000
# State: 核，节
#   省: 1.0000
# State: ，节省
#   人: 1.0000
# State: 节省人
#   力: 1.0000
# State: 省人力
#   资: 1.0000
# State: 人力资
#   源: 1.0000
# State: 力资源
#   。: 0.5000
#   去: 0.5000
# State: 资源。
#   财: 1.0000
# State: 源。财
#   经: 1.0000
# State: 。财经
#   这: 1.0000
# State: 财经这
#   几: 1.0000
# State: 经这几
#   年: 1.0000
# State: 这几年
#   在: 1.0000
# State: 几年在
#   世: 1.0000
# State: 年在世
#   界: 1.0000
# State: 在世界
#   名: 1.0000
# State: 世界名
#   牌: 1.0000
# State: 界名牌
#   大: 1.0000
# State: 名牌大
#   学: 1.0000
# State: 牌大学
#   里: 1.0000
# State: 大学里
#   招: 1.0000
# State: 学里招
#   了: 1.0000
# State: 里招了
#   很: 1.0000
# State: 招了很
#   多: 1.0000
# State: 了很多
#   人: 1.0000
# State: 很多人
#   ，: 1.0000
# State: 多人，
#   先: 1.0000
# State: 人，先
#   派: 1.0000
# State: ，先派
#   到: 1.0000
# State: 先派到
#   非: 1.0000
# State: 派到非
#   洲: 1.0000
# State: 到非洲
#   去: 1.0000
# State: 非洲去
#   做: 1.0000
# State: 洲去做
#   P: 1.0000
# State: 去做P
#   F: 1.0000
# State: 做PF
#   C: 1.0000
# State: PFC
#   。: 0.5000
#   要: 0.5000
# State: FC。
#   P: 1.0000
# State: C。P
#   F: 1.0000
# State: 。PF
#   C: 1.0000
# State: FC要
#   做: 1.0000
# State: C要做
#   核: 1.0000
# State: 要做核
#   算: 1.0000
# State: 做核算
#   ，: 1.0000
# State: 核算，
#   核: 1.0000
# State: 算，核
#   算: 1.0000
# State: ，核算
#   就: 1.0000
# State: 核算就
#   一: 1.0000
# State: 算就一
#   定: 1.0000
# State: 就一定
#   要: 1.0000
# State: 定要懂
#   业: 1.0000
# State: 要懂业
#   务: 1.0000
# State: 懂业务
#   ，: 1.0000
# State: 业务，
#   就: 1.0000
# State: 务，就
#   一: 1.0000
# State: ，就一
#   定: 1.0000
# State: 定要去
#   看: 1.0000
# State: 要去看
#   基: 1.0000
# State: 去看基
#   站: 1.0000
# State: 看基站
#   、: 1.0000
# State: 基站、
#   板: 1.0000
# State: 站、板
#   件: 1.0000
# State: 、板件
#   …: 1.0000
# State: 板件…
#   …: 1.0000
# State: 件……
#   是: 1.0000
# State: ……是
#   什: 1.0000
# State: …是什
#   么: 1.0000
# State: 什么，
#   这: 1.0000
# State: 么，这
#   样: 1.0000
# State: ，这样
#   他: 0.5000
#   大: 0.5000
# State: 这样他
#   对: 1.0000
# State: 样他对
#   业: 1.0000
# State: 他对业
#   务: 1.0000
# State: 对业务
#   有: 1.0000
# State: 业务有
#   一: 1.0000
# State: 务有一
#   点: 1.0000
# State: 有一点
#   理: 1.0000
# State: 一点理
#   解: 1.0000
# State: 点理解
#   ；: 1.0000
# State: 理解；
#   不: 1.0000
# State: 解；不
#   理: 1.0000
# State: ；不理
#   解: 1.0000
# State: 不理解
#   业: 1.0000
# State: 理解业
#   务: 1.0000
# State: 解业务
#   的: 1.0000
# State: 业务的
#   财: 1.0000
# State: 务的财
#   经: 1.0000
# State: 的财经
#   人: 1.0000
# State: 财经人
#   员: 1.0000
# State: 经人员
#   ，: 1.0000
# State: 员，只
#   能: 1.0000
# State: ，只能
#   做: 1.0000
# State: 只能做
#   会: 1.0000
# State: 能做会
#   计: 1.0000
# State: 做会计
#   。: 1.0000
# State: 会计。
#   了: 1.0000
# State: 计。了
#   解: 1.0000
# State: 。了解
#   两: 1.0000
# State: 了解两
#   年: 1.0000
# State: 解两年
#   以: 1.0000
# State: 两年以
#   后: 1.0000
# State: 年以后
#   ，: 1.0000
# State: 以后，
#   从: 1.0000
# State: 后，从
#   基: 1.0000
# State: ，从基
#   层: 1.0000
# State: 从基层
#   C: 1.0000
# State: 基层C
#   F: 1.0000
# State: 层CF
#   O: 1.0000
# State: CFO
#   、: 1.0000
# State: FO、
#   精: 1.0000
# State: O、精
#   算: 1.0000
# State: 、精算
#   师: 1.0000
# State: 精算师
#   …: 1.0000
# State: 算师…
#   …: 1.0000
# State: 师……
#   他: 1.0000
# State: ……他
#   慢: 1.0000
# State: …他慢
#   慢: 1.0000
# State: 他慢慢
#   循: 1.0000
# State: 慢慢循
#   环: 1.0000
# State: 慢循环
#   上: 1.0000
# State: 循环上
#   升: 1.0000
# State: 环上升
#   ，: 1.0000
# State: 升，最
#   后: 1.0000
# State: ，最后
#   到: 1.0000
# State: 最后到
#   机: 1.0000
# State: 后到机
#   关: 1.0000
# State: 到机关
#   来: 1.0000
# State: 机关来
#   ，: 1.0000
# State: 关来，
#   机: 1.0000
# State: 来，机
#   关: 1.0000
# State: ，机关
#   就: 1.0000
# State: 机关就
#   没: 1.0000
# State: 关就没
#   有: 1.0000
# State: 就没有
#   了: 1.0000
# State: 没有了
#   “: 1.0000
# State: 有了“
#   空: 1.0000
# State: 了“空
#   军: 1.0000
# State: “空军
#   司: 1.0000
# State: 空军司
#   令: 1.0000
# State: 军司令
#   ”: 1.0000
# State: 司令”
#   ，: 1.0000
# State: 令”，
#   而: 1.0000
# State: ”，而
#   是: 1.0000
# State: ，而是
#   知: 0.5000
#   自: 0.5000
# State: 而是知
#   晓: 1.0000
# State: 是知晓
#   项: 1.0000
# State: 知晓项
#   目: 1.0000
# State: 晓项目
#   的: 1.0000
# State: 项目的
#   管: 1.0000
# State: 目的管
#   理: 1.0000
# State: 的管理
#   者: 1.0000
# State: 管理者
#   。: 1.0000
# State: 理者。
#   所: 1.0000
# State: 者。所
#   以: 1.0000
# State: 以，现
#   在: 1.0000
# State: ，现在
#   我: 1.0000
# State: 现在我
#   们: 1.0000
# State: 我们招
#   聘: 1.0000
# State: 们招聘
#   的: 1.0000
# State: 聘的系
#   统: 1.0000
# State: 的系统
#   工: 1.0000
# State: 系统工
#   程: 1.0000
# State: 统工程
#   科: 1.0000
# State: 工程科
#   学: 1.0000
# State: 程科学
#   家: 1.0000
# State: 科学家
#   、: 1.0000
# State: 学家、
#   博: 1.0000
# State: 家、博
#   士: 1.0000
# State: 、博士
#   ，: 1.0000
# State: 博士，
#   也: 1.0000
# State: 士，也
#   是: 1.0000
# State: ，也是
#   先: 1.0000
# State: 也是先
#   到: 1.0000
# State: 是先到
#   产: 1.0000
# State: 先到产
#   品: 1.0000
# State: 到产品
#   线: 1.0000
# State: 产品线
#   ，: 1.0000
# State: 品线，
#   从: 1.0000
# State: 线，从
#   产: 1.0000
# State: ，从产
#   品: 1.0000
# State: 从产品
#   到: 1.0000
# State: 产品到
#   开: 1.0000
# State: 品到开
#   发: 1.0000
# State: 到开发
#   …: 1.0000
# State: 开发…
#   …: 1.0000
# State: 发……
#   再: 1.0000
# State: ……再
#   一: 1.0000
# State: …再一
#   点: 1.0000
# State: 再一点
#   点: 1.0000
# State: 一点点
#   升: 1.0000
# State: 点点升
#   级: 1.0000
# State: 点升级
#   上: 1.0000
# State: 升级上
#   来: 1.0000
# State: 级上来
#   ，: 1.0000
# State: 上来，
#   不: 0.5000
#   但: 0.5000
# State: 来，不
#   是: 1.0000
# State: 不是一
#   来: 1.0000
# State: 是一来
#   就: 1.0000
# State: 一来就
#   能: 1.0000
# State: 来就能
#   够: 1.0000
# State: 就能够
#   做: 1.0000
# State: 能够做
#   规: 1.0000
# State: 够做规
#   划: 1.0000
# State: 做规划
#   的: 1.0000
# State: 规划的
#   。: 1.0000
# State: 划的。
#   第: 1.0000
# State: 。第二
#   ，: 1.0000
# State: 第二，
#   我: 0.5000
#   在: 0.5000
# State: 二，我
# ...
# State: ，让优秀人
#   才: 1.0000
# State: 让优秀人才
#   涌: 1.0000
# State: 优秀人才涌
#   现: 1.0000
# State: 秀人才涌现
#   ，: 1.0000
# State: 人才涌现，
#   英: 1.0000
# State: 才涌现，英
#   雄: 1.0000
# State: 涌现，英雄
#   倍: 0.5000
#   辈: 0.5000
# State: 现，英雄倍
#   出: 1.0000
# State: ，英雄倍出
#   。: 1.0000
# State: 英雄倍出。
#   华: 1.0000
# State: 雄倍出。华
#   为: 1.0000
# State: 倍出。华为
#   公: 1.0000
# State: 出。华为公
#   司: 1.0000
# State: 。华为公司
#   一: 1.0000
# State: 华为公司一
#   直: 1.0000
# State: 为公司一直
#   贯: 1.0000
# State: 公司一直贯
#   彻: 1.0000
# State: 司一直贯彻
#   选: 1.0000
# State: 一直贯彻选
#   拔: 1.0000
# State: 直贯彻选拔
#   制: 1.0000
# State: 贯彻选拔制
#   ，: 1.0000
# State: 彻选拔制，
#   因: 1.0000
# State: 选拔制，因
#   为: 1.0000
# State: 拔制，因为
#   人: 1.0000
# State: 制，因为人
#   才: 1.0000
# State: ，因为人才
#   不: 1.0000
# State: 因为人才不
#   是: 1.0000
# State: 为人才不是
#   靠: 1.0000
# State: 人才不是靠
#   培: 1.0000
# State: 才不是靠培
#   养: 1.0000
# State: 不是靠培养
#   ，: 1.0000
# State: 是靠培养，
#   而: 1.0000
# State: 靠培养，而
#   是: 1.0000
# State: 培养，而是
#   自: 1.0000
# State: 养，而是自
#   我: 1.0000
# State: ，而是自我
#   成: 1.0000
# State: 而是自我成
#   长: 1.0000
# State: 是自我成长
#   ，: 1.0000
# State: 自我成长，
#   我: 1.0000
# State: 我成长，我
#   们: 1.0000
# State: 成长，我们
#   要: 1.0000
# State: 长，我们要
#   创: 1.0000
# State: ，我们要创
#   造: 1.0000
# State: 我们要创造
#   人: 0.5000
#   一: 0.5000
# State: 们要创造人
#   才: 1.0000
# State: 长的土壤，
#   就: 1.0000
# State: 的土壤，就
#   如: 1.0000
# State: 土壤，就如
#   “: 1.0000
# State: 壤，就如“
#   一: 1.0000
# State: ，就如“一
#   杯: 1.0000
# State: 就如“一杯
#   咖: 1.0000
# State: 如“一杯咖
#   啡: 1.0000
# State: “一杯咖啡
#   吸: 1.0000
# State: 一杯咖啡吸
#   收: 1.0000
# State: 杯咖啡吸收
#   宇: 1.0000
# State: 咖啡吸收宇
#   宙: 1.0000
# State: 啡吸收宇宙
#   能: 1.0000
# State: 吸收宇宙能
#   量: 1.0000
# State: 收宇宙能量
#   ”: 1.0000
# State: 宇宙能量”
#   。: 1.0000
# State: 宙能量”。
#   我: 1.0000
# State: 能量”。我
#   们: 1.0000
# State: 量”。我们
#   不: 1.0000
# State: ”。我们不
#   要: 1.0000
# State: 。我们不要
#   给: 1.0000
# State: 我们不要给
#   高: 1.0000
# State: 们不要给高
#   级: 1.0000
# State: 不要给高级
#   专: 1.0000
# State: 要给高级专
#   家: 1.0000
# State: 给高级专家
#   担: 1.0000
# State: 高级专家担
#   负: 1.0000
# State: 级专家担负
#   太: 1.0000
# State: 专家担负太
#   多: 1.0000
# State: 家担负太多
#   管: 1.0000
# State: 担负太多管
#   理: 1.0000
# State: 负太多管理
#   人: 1.0000
# State: 太多管理人
#   才: 1.0000
# State: 多管理人才
#   的: 1.0000
# State: 管理人才的
#   责: 1.0000
# State: 理人才的责
#   任: 1.0000
# State: 人才的责任
#   ，: 1.0000
# State: 才的责任，
#   不: 1.0000
# State: 的责任，不
#   要: 1.0000
# State: 责任，不要
#   搞: 1.0000
# State: 任，不要搞
#   “: 1.0000
# State: ，不要搞“
#   拉: 1.0000
# State: 不要搞“拉
#   郎: 1.0000
# State: 要搞“拉郎
#   配: 1.0000
# State: 搞“拉郎配
#   ”: 1.0000
# State: “拉郎配”
#   ，: 1.0000
# State: 拉郎配”，
#   要: 1.0000
# State: 郎配”，要
#   给: 1.0000
# State: 配”，要给
#   他: 1.0000
# State: ”，要给他
#   们: 1.0000
# State: ，要给他们
#   自: 1.0000
# State: 要给他们自
#   由: 1.0000
# State: 给他们自由
#   度: 1.0000
# State: 他们自由度
#   ，: 1.0000
# State: 们自由度，
#   他: 1.0000
# State: 自由度，他
#   有: 1.0000
# State: 由度，他有
#   多: 1.0000
# State: 度，他有多
#   大: 1.0000
# State: ，他有多大
#   能: 1.0000
# State: 他有多大能
#   量: 1.0000
# State: 有多大能量
#   就: 1.0000
# State: 多大能量就
#   发: 1.0000
# State: 大能量就发
#   挥: 1.0000
# State: 能量就发挥
#   多: 1.0000
# State: 量就发挥多
#   大: 1.0000
# State: 就发挥多大
#   能: 1.0000
# State: 发挥多大能
#   量: 1.0000
# State: 挥多大能量
#   。: 1.0000
# State: 多大能量。
#   第: 1.0000
# State: 大能量。第
#   一: 1.0000
# State: 能量。第一
#   ，: 1.0000
# State: 量。第一，
#   高: 1.0000
# State: 。第一，高
#   端: 1.0000
# State: 第一，高端
#   技: 1.0000
# State: 一，高端技
#   术: 1.0000
# State: ，高端技术
#   人: 1.0000
# State: 技术人才在
#   适: 1.0000
# State: 术人才在适
#   合: 1.0000
# State: 人才在适合
#   的: 1.0000
# State: 才在适合的
#   工: 1.0000
# State: 在适合的工
#   作: 1.0000
# State: 适合的工作
#   岗: 1.0000
# State: 合的工作岗
#   位: 1.0000
# State: 工作岗位，
#   一: 1.0000
# State: 作岗位，一
#   定: 1.0000
# State: 岗位，一定
#   会: 1.0000
# State: 位，一定会
#   显: 1.0000
# State: ，一定会显
#   出: 1.0000
# State: 一定会显出
#   他: 1.0000
# State: 定会显出他
#   的: 1.0000
# State: 会显出他的
#   价: 1.0000
# State: 显出他的价
#   值: 1.0000
# State: 出他的价值
#   来: 1.0000
# State: 他的价值来
#   ，: 1.0000
# State: 的价值来，
#   然: 1.0000
# State: 价值来，然
#   后: 1.0000
# State: 值来，然后
#   在: 1.0000
# State: 来，然后在
#   价: 1.0000
# State: ，然后在价
#   值: 1.0000
# State: 然后在价值
#   体: 1.0000
# State: 后在价值体
#   系: 1.0000
# State: 在价值体系
#   去: 1.0000
# State: 价值体系去
#   评: 1.0000
# State: 值体系去评
#   价: 1.0000
# State: 体系去评价
#   他: 1.0000
# State: 系去评价他
#   。: 1.0000
# State: 评价他。我
#   们: 1.0000
# State: 价他。我们
#   可: 1.0000
# State: 他。我们可
#   以: 1.0000
# State: 。我们可以
#   设: 0.5000
#   安: 0.5000
# State: 我们可以设
#   一: 1.0000
# State: 们可以设一
#   个: 1.0000
# State: 可以设一个
#   高: 1.0000
# State: 以设一个高
#   端: 1.0000
# State: 设一个高端
#   投: 1.0000
# State: 一个高端投
#   诉: 1.0000
# State: 个高端投诉
#   平: 1.0000
# State: 高端投诉平
#   台: 1.0000
# State: 端投诉平台
#   ，: 1.0000
# State: 投诉平台，
#   大: 1.0000
# State: 诉平台，大
#   家: 1.0000
# State: 平台，大家
#   有: 1.0000
# State: 台，大家有
#   问: 1.0000
# State: ，大家有问
#   题: 1.0000
# State: 大家有问题
#   就: 1.0000
# State: 家有问题就
#   写: 1.0000
# State: 有问题就写
#   邮: 1.0000
# State: 问题就写邮
#   件: 1.0000
# State: 题就写邮件
#   到: 1.0000
# State: 就写邮件到
#   这: 1.0000
# State: 写邮件到这
#   个: 1.0000
# State: 邮件到这个
#   平: 1.0000
# State: 件到这个平
#   台: 1.0000
# State: 到这个平台
#   ，: 1.0000
# State: 这个平台，
#   人: 1.0000
# State: 个平台，人
#   力: 1.0000
# State: 平台，人力
#   资: 1.0000
# State: 台，人力资
#   源: 1.0000
# State: ，人力资源
#   去: 1.0000
# State: 人力资源去
#   听: 1.0000
# State: 力资源去听
#   他: 1.0000
# State: 资源去听他
#   倾: 1.0000
# State: 源去听他倾
#   诉: 1.0000
# State: 去听他倾诉
#   ，: 1.0000
# State: 听他倾诉，
#   做: 1.0000
# State: 他倾诉，做
#   成: 1.0000
# State: 倾诉，做成
#   纪: 1.0000
# State: 诉，做成纪
#   要: 1.0000
# State: ，做成纪要
#   报: 1.0000
# State: 做成纪要报
#   给: 1.0000
# State: 成纪要报给
#   有: 1.0000
# State: 纪要报给有
#   关: 1.0000
# State: 要报给有关
#   部: 1.0000
# State: 报给有关部
#   门: 1.0000
# State: 给有关部门
#   帮: 1.0000
# State: 有关部门帮
#   助: 1.0000
# State: 关部门帮助
#   他: 1.0000
# State: 部门帮助他
#   调: 1.0000
# State: 门帮助他调
#   整: 1.0000
# State: 帮助他调整
#   。: 1.0000
# State: 助他调整。
#   我: 1.0000
# State: 他调整。我
#   们: 1.0000
# State: 调整。我们
#   可: 1.0000
# State: 整。我们可
#   以: 1.0000
# State: 我们可以安
#   排: 1.0000
# State: 们可以安排
#   一: 1.0000
# State: 可以安排一
#   些: 1.0000
# State: 以安排一些
#   人: 1.0000
# State: 安排一些人
#   际: 1.0000
# State: 排一些人际
#   理: 1.0000
# State: 一些人际理
#   解: 1.0000
# State: 些人际理解
#   力: 1.0000
# State: 人际理解力
#   强: 1.0000
# State: 际理解力强
#   、: 1.0000
# State: 理解力强、
#   熟: 1.0000
# State: 解力强、熟
#   悉: 1.0000
# State: 力强、熟悉
#   华: 1.0000
# State: 强、熟悉华
#   为: 1.0000
# State: 、熟悉华为
#   流: 1.0000
# State: 熟悉华为流
#   程: 1.0000
# State: 悉华为流程
#   、: 1.0000
# State: 华为流程、
#   善: 1.0000
# State: 为流程、善
#   于: 1.0000
# State: 流程、善于
#   沟: 1.0000
# State: 程、善于沟
#   通: 1.0000
# State: 、善于沟通
#   、: 1.0000
# State: 善于沟通、
#   善: 1.0000
# State: 于沟通、善
#   于: 1.0000
# State: 沟通、善于
#   团: 1.0000
# State: 通、善于团
#   结: 1.0000
# State: 、善于团结
#   人: 1.0000
# State: 善于团结人
#   的: 1.0000
# State: 于团结人的
#   老: 1.0000
# State: 团结人的老
#   员: 1.0000
# State: 结人的老员
#   工: 1.0000
# State: 人的老员工
#   ，: 1.0000
# State: 的老员工，
#   到: 1.0000
# State: 老员工，到
#   导: 1.0000
# State: 员工，到导
#   师: 1.0000
# State: 工，到导师
#   部: 1.0000
# State: ，到导师部
#   去: 1.0000
# State: 到导师部去
#   听: 1.0000
# State: 导师部去听
#   群: 1.0000
# State: 师部去听群
#   众: 1.0000
# State: 部去听群众
#   的: 1.0000
# State: 去听群众的
#   声: 1.0000
# State: 听群众的声
#   音: 1.0000
# State: 群众的声音
#   ，: 1.0000
# State: 众的声音，
#   调: 1.0000
# State: 的声音，调
#   节: 1.0000
# State: 声音，调节
#   矛: 1.0000
# State: 音，调节矛
#   盾: 1.0000
# State: ，调节矛盾
#   。: 1.0000
# State: 调节矛盾。
#   第: 1.0000
# State: 节矛盾。第
#   二: 1.0000
# State: 矛盾。第二
#   ，: 1.0000
# State: 盾。第二，
#   在: 1.0000
# State: 。第二，在
#   人: 1.0000
# State: 第二，在人
#   才: 1.0000
# State: 二，在人才
#   成: 1.0000
# State: ，在人才成
#   长: 1.0000
# State: 在人才成长
#   过: 1.0000
# State: 人才成长过
#   程: 1.0000
# State: 才成长过程
#   中: 1.0000
# State: 成长过程中
#   ，: 1.0000
# State: 长过程中，
#   我: 1.0000
# State: 过程中，我
#   们: 1.0000
# State: 程中，我们
#   要: 1.0000
# State: 中，我们要
#   创: 1.0000
# State: 们要创造一
#   个: 1.0000
# State: 要创造一个
#   宽: 1.0000
# State: 创造一个宽
#   容: 1.0000
# State: 造一个宽容
#   的: 1.0000
# State: 一个宽容的
#   环: 1.0000
# State: 个宽容的环
#   境: 1.0000
# State: ，让大家愿
#   意: 1.0000
# State: 让大家愿意
#   畅: 1.0000
# State: 大家愿意畅
#   所: 1.0000
# State: 家愿意畅所
#   欲: 1.0000
# State: 愿意畅所欲
#   言: 1.0000
# State: 意畅所欲言
#   ，: 1.0000
# State: 所欲言，互
#   相: 1.0000
# State: 欲言，互相
#   启: 1.0000
# State: 言，互相启
#   发: 1.0000
# State: ，互相启发
#   ，: 1.0000
# State: 互相启发，
#   把: 1.0000
# State: 相启发，把
#   思: 1.0000
# State: 启发，把思
#   想: 1.0000
# State: 发，把思想
#   炸: 1.0000
# State: ，把思想炸
#   开: 1.0000
# State: 把思想炸开
#   。: 1.0000
# State: 思想炸开。
#   一: 1.0000
# State: 想炸开。一
#   是: 1.0000
# State: 炸开。一是
#   ，: 1.0000
# State: 开。一是，
#   喝: 1.0000
# State: 。一是，喝
#   咖: 1.0000
# State: 一是，喝咖
#   啡: 1.0000
# State: 是，喝咖啡
#   是: 1.0000
# State: ，喝咖啡是
#   一: 1.0000
# State: 喝咖啡是一
#   种: 1.0000
# State: 咖啡是一种
#   形: 1.0000
# State: 啡是一种形
#   式: 1.0000
# State: 是一种形式
#   ，: 1.0000
# State: 一种形式，
#   网: 1.0000
# State: 种形式，网
#   聊: 1.0000
# State: 形式，网聊
#   也: 1.0000
# State: 式，网聊也
#   是: 1.0000
# State: ，网聊也是
#   “: 1.0000
# State: 网聊也是“
#   喝: 1.0000
# State: 聊也是“喝
#   咖: 1.0000
# State: 也是“喝咖
#   啡: 1.0000
# State: 是“喝咖啡
#   ”: 1.0000
# State: “喝咖啡”
#   ，: 1.0000
# State: 喝咖啡”，
#   比: 1.0000
# State: 咖啡”，比
#   如: 1.0000
# State: 啡”，比如
#   2: 1.0000
# State: ”，比如2
#   0: 1.0000
# State: ，比如20
#   1: 1.0000
# State: 比如201
#   2: 1.0000
# State: 如2012
#   实: 1.0000
# State: 2012实
#   验: 1.0000
# State: 012实验
#   室: 1.0000
# State: 12实验室
#   在: 1.0000
# State: 2实验室在
#   群: 1.0000
# State: 实验室在群
#   里: 1.0000
# State: 验室在群里
#   的: 1.0000
# State: 室在群里的
#   讨: 1.0000
# State: 在群里的讨
#   论: 1.0000
# State: 群里的讨论
#   就: 1.0000
# State: 里的讨论就
#   很: 1.0000
# State: 的讨论就很
#   激: 1.0000
# State: 讨论就很激
#   烈: 1.0000
# State: 论就很激烈
#   ，: 1.0000
# State: 就很激烈，
#   关: 1.0000
# State: 很激烈，关
#   于: 1.0000
# State: 激烈，关于
#   软: 1.0000
# State: 烈，关于软
#   件: 1.0000
# State: ，关于软件
#   突: 1.0000
# State: 关于软件突
#   围: 1.0000
# State: 于软件突围
#   方: 1.0000
# State: 软件突围方
#   向: 1.0000
# State: 件突围方向
#   在: 1.0000
# State: 突围方向在
#   心: 1.0000
# State: 围方向在心
#   声: 1.0000
# State: 方向在心声
#   社: 1.0000
# State: 向在心声社
#   区: 1.0000
# State: 在心声社区
#   的: 1.0000
# State: 心声社区的
#   回: 1.0000
# State: 声社区的回
#   帖: 1.0000
# State: 社区的回帖
#   有: 1.0000
# State: 区的回帖有
#   1: 1.0000
# State: 的回帖有1
#   5: 1.0000
# State: 回帖有15
#   0: 1.0000
# State: 帖有150
#   0: 1.0000
# State: 有1500
#   多: 1.0000
# State: 1500多
#   条: 1.0000
# State: 500多条
#   ，: 1.0000
# State: 00多条，
#   别: 1.0000
# State: 0多条，别
#   看: 1.0000
# State: 多条，别看
#   这: 1.0000
# State: 条，别看这
#   一: 1.0000
# State: ，别看这一
#   片: 1.0000
# State: 别看这一片
#   骂: 1.0000
# State: 看这一片骂
#   声: 1.0000
# State: 这一片骂声
#   ，: 1.0000
# State: 一片骂声，
#   这: 1.0000
# State: 片骂声，这
#   就: 1.0000
# State: 骂声，这就
#   是: 1.0000
# State: 声，这就是
#   贵: 1.0000
# State: ，这就是贵
#   人: 1.0000
# State: 这就是贵人
#   指: 1.0000
# State: 就是贵人指
#   点: 1.0000
# State: 是贵人指点
#   、: 1.0000
# State: 贵人指点、
#   高: 1.0000
# State: 人指点、高
#   僧: 1.0000
# State: 指点、高僧
#   开: 1.0000
# State: 点、高僧开
#   光: 1.0000
# State: 、高僧开光
#   、: 1.0000
# State: 高僧开光、
#   西: 1.0000
# State: 僧开光、西
#   汉: 1.0000
# State: 开光、西汉
#   张: 1.0000
# State: 光、西汉张
#   良: 1.0000
# State: 、西汉张良
#   在: 1.0000
# State: 西汉张良在
#   桥: 1.0000
# State: 汉张良在桥
#   头: 1.0000
# State: 张良在桥头
#   获: 1.0000
# State: 良在桥头获
#   得: 1.0000
# State: 在桥头获得
#   的: 1.0000
# State: 桥头获得的
#   天: 1.0000
# State: 头获得的天
#   书: 1.0000
# State: 获得的天书
#   …: 1.0000
# State: 得的天书…
#   …: 1.0000
# State: 的天书……
#   。: 1.0000
# State: 天书……。
#   对: 1.0000
# State: 书……。对
#   新: 1.0000
# State: ……。对新
#   员: 1.0000
# State: …。对新员
#   工: 1.0000
# State: 。对新员工
#   是: 1.0000
# State: 对新员工是
#   多: 1.0000
# State: 新员工是多
#   么: 1.0000
# State: 员工是多么
#   好: 1.0000
# State: 工是多么好
#   的: 1.0000
# State: 是多么好的
#   指: 1.0000
# State: 多么好的指
#   引: 1.0000
# State: 么好的指引
#   。: 1.0000
# State: 好的指引。
#   我: 1.0000
# State: 的指引。我
#   为: 1.0000
# State: 指引。我为
#   什: 1.0000
# State: 引。我为什
#   么: 1.0000
# State: 。我为什么
#   不: 1.0000
# State: 我为什么不
#   愿: 1.0000
# State: 为什么不愿
#   意: 1.0000
# State: 什么不愿意
#   网: 1.0000
# State: 么不愿意网
#   聊: 1.0000
# State: 不愿意网聊
#   ，: 1.0000
# State: 愿意网聊，
#   愿: 1.0000
# State: 意网聊，愿
#   意: 1.0000
# State: 网聊，愿意
#   喝: 1.0000
# State: 聊，愿意喝
#   咖: 1.0000
# State: ，愿意喝咖
#   啡: 1.0000
# State: 愿意喝咖啡
#   呢: 1.0000
# State: 意喝咖啡呢
#   ？: 1.0000
# State: 喝咖啡呢？
#   我: 1.0000
# State: 咖啡呢？我
#   认: 1.0000
# State: 啡呢？我认
#   为: 1.0000
# State: 呢？我认为
#   讲: 1.0000
# State: ？我认为讲
#   话: 1.0000
# State: 我认为讲话
#   互: 1.0000
# State: 认为讲话互
#   动: 1.0000
# State: 为讲话互动
#   比: 1.0000
# State: 讲话互动比
#   文: 1.0000
# State: 话互动比文
#   字: 1.0000
# State: 互动比文字
#   互: 1.0000
# State: 动比文字互
#   动: 1.0000
# State: 比文字互动
#   效: 1.0000
# State: 文字互动效
#   率: 1.0000
# State: 字互动效率
#   高: 1.0000
# State: 互动效率高
#   、: 1.0000
# State: 动效率高、
#   表: 1.0000
# State: 效率高、表
#   述: 1.0000
# State: 率高、表述
#   更: 1.0000
# State: 高、表述更
#   清: 1.0000
# State: 、表述更清
#   楚: 1.0000
# State: 表述更清楚
#   。: 1.0000
# State: 述更清楚。
#   二: 1.0000
# State: 更清楚。二
#   是: 1.0000
# State: 清楚。二是
#   ，: 1.0000
# State: 楚。二是，
#   高: 1.0000
# State: 。二是，高
#   级: 1.0000
# State: 二是，高级
#   专: 1.0000
# State: 是，高级专
#   家: 1.0000
# State: ，高级专家
#   要: 1.0000
# State: 高级专家要
#   用: 1.0000
# State: 级专家要用
#   更: 1.0000
# State: 专家要用更
#   多: 1.0000
# State: 家要用更多
#   精: 1.0000
# State: 要用更多精
#   力: 1.0000
# State: 用更多精力
#   来: 1.0000
# State: 更多精力来
#   读: 1.0000
# State: 多精力来读
#   文: 1.0000
# State: 精力来读文
#   献: 1.0000
# State: 力来读文献
#   ，: 1.0000
# State: 来读文献，
#   而: 0.5000
#   写: 0.5000
# State: 读文献，而
#   不: 1.0000
# State: 文献，而不
#   是: 1.0000
# State: 献，而不是
#   埋: 1.0000
# State: ，而不是埋
#   头: 1.0000
# State: 而不是埋头
#   做: 1.0000
# State: 不是埋头做
#   事: 1.0000
# State: 是埋头做事
#   。: 1.0000
# State: 埋头做事。
#   比: 1.0000
# State: 头做事。比
#   如: 1.0000
# State: 做事。比如
#   ，: 1.0000
# State: 事。比如，
#   把: 1.0000
# State: 。比如，把
#   一: 1.0000
# State: 比如，把一
#   半: 1.0000
# State: 如，把一半
#   时: 1.0000
# State: ，把一半时
#   间: 1.0000
# State: 把一半时间
#   用: 1.0000
# State: 一半时间用
#   来: 1.0000
# State: 半时间用来
#   读: 1.0000
# State: 时间用来读
#   文: 1.0000
# State: 间用来读文
#   献: 1.0000
# State: 用来读文献
#   ，: 1.0000
# State: 读文献，写
#   写: 1.0000
# State: 文献，写写
#   感: 1.0000
# State: 献，写写感
#   想: 1.0000
# State: ，写写感想
#   。: 1.0000
# State: 写写感想。
#   三: 1.0000
# State: 写感想。三
#   是: 1.0000
# State: 感想。三是
#   ，: 1.0000
# State: 想。三是，
#   我: 1.0000
# State: 。三是，我
#   们: 1.0000
# State: 三是，我们
#   “: 1.0000
# State: 是，我们“
#   黄: 1.0000
# State: ，我们“黄
#   大: 1.0000
# State: 我们“黄大
#   年: 1.0000
# State: 们“黄大年
#   茶: 1.0000
# State: “黄大年茶
#   思: 1.0000
# State: 黄大年茶思
#   屋: 1.0000
# State: 大年茶思屋
#   ”: 1.0000
# State: 年茶思屋”
#   应: 1.0000
# State: 茶思屋”应
#   该: 1.0000
# State: 思屋”应该
#   号: 1.0000
# State: 屋”应该号
#   召: 1.0000
# State: ”应该号召
#   所: 1.0000
# State: 应该号召所
#   有: 1.0000
# State: 该号召所有
#   员: 1.0000
# State: 号召所有员
#   工: 1.0000
# State: 召所有员工
#   把: 1.0000
# State: 所有员工把
#   他: 1.0000
# State: 有员工把他
#   认: 1.0000
# State: 员工把他认
#   为: 1.0000
# State: 工把他认为
#   好: 1.0000
# State: 把他认为好
#   的: 1.0000
# State: 他认为好的
#   文: 1.0000
# State: 认为好的文
#   献: 1.0000
# State: 为好的文献
#   转: 1.0000
# State: 好的文献转
#   帖: 1.0000
# State: 的文献转帖
#   过: 1.0000
# State: 文献转帖过
#   来: 1.0000
# State: 献转帖过来
#   ，: 1.0000
# State: 转帖过来，
#   如: 1.0000
# State: 帖过来，如
#   果: 1.0000
# State: 过来，如果
#   涉: 1.0000
# State: 来，如果涉
#   及: 1.0000
# State: ，如果涉及
#   知: 1.0000
# State: 如果涉及知
#   识: 1.0000
# State: 果涉及知识
#   产: 1.0000
# State: 涉及知识产
#   权: 1.0000
# State: 及知识产权
#   问: 1.0000
# State: 知识产权问
#   题: 1.0000
# State: 识产权问题
#   ，: 1.0000
# State: 产权问题，
#   就: 1.0000
# State: 权问题，就
#   把: 1.0000
# State: 问题，就把
#   索: 1.0000
# State: 题，就把索
#   引: 1.0000
# State: ，就把索引
#   贴: 1.0000
# State: 就把索引贴
#   上: 1.0000
# State: 把索引贴上
#   来: 1.0000
# State: 索引贴上来
#   就: 1.0000
# State: 引贴上来就
#   行: 1.0000
# State: 贴上来就行
#   ，: 1.0000
# State: 上来就行，
#   大: 1.0000
# State: 来就行，大
#   家: 1.0000
# State: 就行，大家
#   再: 1.0000
# State: 行，大家再
#   去: 1.0000
# State: ，大家再去
#   那: 1.0000
# State: 大家再去那
#   个: 1.0000
# State: 家再去那个
#   网: 1.0000
# State: 再去那个网
#   站: 1.0000
# State: 去那个网站
#   上: 1.0000
# State: 那个网站上
#   查: 1.0000
# State: 个网站上查
#   阅: 1.0000
# State: 网站上查阅
#   ，: 1.0000
# State: 站上查阅，
#   这: 1.0000
# State: 上查阅，这
#   也: 1.0000
# State: 查阅，这也
#   是: 1.0000
# State: 阅，这也是
#   一: 1.0000
# State: ，这也是一
#   个: 1.0000
# State: 这也是一个
#   沟: 1.0000
# State: 也是一个沟
#   通: 1.0000
# State: 是一个沟通
#   方: 1.0000
# State: 一个沟通方
#   式: 1.0000
# State: 个沟通方式
#   。: 1.0000
# State: 沟通方式。
#   今: 1.0000
# State: 通方式。今
#   天: 1.0000
# State: 方式。今天
#   听: 1.0000
# State: 式。今天听
#   了: 1.0000
# State: 。今天听了
#   汇: 1.0000
# State: 今天听了汇
#   报: 1.0000
# State: 天听了汇报
#   ，: 1.0000
# State: 听了汇报，
#   你: 1.0000
# State: 了汇报，你
#   们: 1.0000
# State: 汇报，你们
#   工: 1.0000
# State: 报，你们工
#   作: 1.0000
# State: ，你们工作
#   的: 1.0000
# State: 你们工作的
#   基: 1.0000
# State: 们工作的基
#   本: 1.0000
# State: 工作的基本
#   思: 1.0000
# State: 作的基本思
#   路: 1.0000
# State: 的基本思路
#   是: 1.0000
# State: 基本思路是
#   清: 1.0000
# State: 本思路是清
#   晰: 1.0000
# State: 思路是清晰
#   的: 1.0000
# State: 路是清晰的
#   。: 1.0000
# State: 是清晰的。
#   历: 1.0000
# State: 清晰的。历
#   史: 1.0000
# State: 晰的。历史
#   滚: 1.0000
# State: 的。历史滚
#   滚: 1.0000
# State: 。历史滚滚
#   向: 1.0000
# State: 历史滚滚向
#   前: 1.0000
# State: 史滚滚向前
#   就: 1.0000
# State: 滚滚向前就
#   会: 1.0000
# State: 滚向前就会
#   有: 1.0000
# State: 向前就会有
#   新: 1.0000
# State: 前就会有新
#   陈: 1.0000
# State: 就会有新陈
#   代: 1.0000
# State: 会有新陈代
#   谢: 1.0000
# State: 有新陈代谢
#   ，: 1.0000
# State: 新陈代谢，
#   有: 1.0000
# State: 陈代谢，有
#   人: 1.0000
# State: 代谢，有人
#   选: 1.0000
# State: 谢，有人选
#   择: 1.0000
# State: ，有人选择
#   离: 1.0000
# State: 有人选择离
#   开: 1.0000
# State: 人选择离开
#   就: 1.0000
# State: 选择离开就
#   会: 1.0000
# State: 择离开就会
#   有: 1.0000
# State: 离开就会有
#   继: 1.0000
# State: 开就会有继
#   任: 1.0000
# State: 就会有继任
#   上: 1.0000
# State: 会有继任上
#   来: 1.0000
# State: 有继任上来
#   ，: 1.0000
# State: 继任上来，
#   但: 1.0000
# State: 任上来，但
#   是: 1.0000
# State: 上来，但是
#   我: 1.0000
# State: 来，但是我
#   们: 1.0000
# State: ，但是我们
#   要: 1.0000
# State: 但是我们要
#   形: 1.0000
# State: 是我们要形
#   成: 1.0000
# State: 我们要形成
#   一: 1.0000
# State: 们要形成一
#   个: 1.0000
# State: 要形成一个
#   良: 1.0000
# State: 形成一个良
#   好: 1.0000
# State: 成一个良好
#   机: 1.0000
# State: 一个良好机
#   制: 1.0000
# State: 个良好机制
#   ，: 1.0000
# State: 良好机制，
#   让: 1.0000
# State: 好机制，让
#   优: 1.0000
# State: 机制，让优
#   秀: 1.0000
# State: 制，让优秀
#   人: 1.0000
# State: 现，英雄辈
#   出: 1.0000
# State: ，英雄辈出
#   。: 1.0000

# %% [markdown]
# 我在Github上找到了2015-2019年每天新闻联播的语料，数据的数量级在千万级别，喂给模型计算。得到的结果更接近于文献中的数据。

# %%
folder_path = 'news_content/'

def read_files(folder_path):
    texts = []
    for filename in os.listdir(folder_path):
        if filename.endswith('.json'):
            file_path = os.path.join(folder_path, filename)
            with open(file_path, 'r', encoding='utf-8') as file:
                data = json.load(file)
                texts.append(data)
    return ''.join(str(texts))

text1 = read_files(folder_path)
# 过滤非字母和非空格字符，并转换为小写
filtered_text1 = ''.join(filter(lambda x: '\u4e00' <= x <= '\u9fff' or x.isspace(), text1))
char_count1 = Counter(filtered_text1)

print(char_count1)
# Out:
# Counter({'的': 301786, '国': 242667, '中': 181505, '在': 113234, '一': 111648, '会': 110464, '人': 108764, '和': 103585, '新': 103106, '大': 101718, '发': 99878, '作': 84672, '全': 79576, '年': 78988, '了': 73124, '展': 69458, '要': 67384, '为': 63928, ' ': 63465, '民': 62935, '方': 62718, '进': 61914, '行': 61624, '出': 61612, '央': 60098, '主': 59886, '平': 59224, '合': 58626, '是': 58562, '政': 57646, '地': 57066, '家': 55278, '联': 54074, '有': 53956, '同': 53884, '动': 53614, '成': 53042, '实': 52986, '业': 52970, '文': 52888, '对': 51406, '日': 51268, '部': 50876, '强': 50726, '关': 50604, '开': 50468, '上': 49824, '近': 49478, '建': 48444, '共': 47103, '重': 46512, '工': 46496, '加': 46236, '不': 44622, '经': 44402, '习': 44304, '力': 43314, '时': 42394, '来': 42062, '党': 42052, '表': 41878, '总': 41834, '生': 41516, '多': 41468, '议': 41414, '视': 41164, '以': 41118, '高': 40774, '个': 40621, '化': 40406, '播': 39514, '天': 39140, '务': 38460, '持': 38366, '等': 37760, '网': 37672, '员': 37638, '法': 37485, '区': 37260, '到': 37014, '长': 36592, '体': 35676, '理': 35496, '委': 34500, '消': 34078, '将': 33532, '推': 33366, '息': 33082, '面': 32986, '代': 32206, '系': 32124, '机': 31672, '现': 31592, '闻': 31426, '制': 31420, '今': 31314, '前': 31174, '这': 31160, '改': 31076, '利': 30670, '好': 30648, '两': 30596, '领': 30502, '定': 30152, '治': 30042, '公': 29978, '美': 29816, '版': 29644, '设': 29614, '字': 28900, '各': 28600, '产': 28254, '通': 28220, '我': 28150, '事': 27816, '于': 27578, '军': 27534, '保': 27238, '月': 27122, '战': 26914, '席': 26736, '次': 26680, '学': 26670, '提': 26660, '能': 26632, '与': 26602, '示': 26222, '分': 25974, '路': 25614, '社': 25548, '统': 25542, '度': 25498, '海': 25480, '济': 25092, '问': 25080, '过': 24902, '革': 24770, '自': 24670, '坚': 24630, '导': 24596, '第': 24592, '下': 24400, '际': 24344, '组': 24210, '内': 24088, '深': 24038, '市': 24016, '安': 23980, '特': 23906, '交': 23872, '题': 23842, '心': 23802, '就': 23658, '十': 23638, '入': 23530, '创': 23052, '正': 23022, '目': 22956, '用': 22928, '调': 22796, '基': 22654, '向': 22206, '书': 22150, '记': 22120, '们': 22066, '克': 21644, '斯': 21638, '三': 21600, '举': 21554, '增': 21458, '外': 21380, '当': 21368, '明': 20978, '场': 20624, '北': 20486, '亚': 20278, '决': 20198, '后': 20126, '协': 20040, '资': 19870, '本': 19830, '更': 19606, '道': 19568, '指': 19418, '院': 19382, '点': 19344, '立': 19320, '最': 19134, '里': 19134, '西': 18988, '村': 18828, '任': 18616, '得': 18609, '报': 18606, '造': 18532, '续': 18242, '界': 18242, '间': 18240, '意': 18224, '南': 18088, '带': 18064, '信': 17920, '期': 17768, '科': 17676, '起': 17628, '布': 17608, '他': 17492, '局': 17396, '世': 17304, '放': 17250, '也': 17212, '首': 17200, '性': 17134, '义': 17104, '从': 17102, '水': 17018, '施': 16898, '万': 16880, '活': 16842, '企': 16812, '项': 16720, '府': 16596, '量': 16474, '并': 16300, '运': 16198, '农': 16016, '见': 16004, '台': 15964, '团': 15942, '相': 15896, '规': 15798, '流': 15796, '式': 15750, '结': 15676, '名': 15594, '之': 15564, '贫': 15438, '支': 15434, '达': 15362, '金': 15286, '护': 15266, '已': 15224, '山': 15188, '京': 15158, '互': 15018, '小': 14930, '位': 14926, '者': 14924, '程': 14802, '江': 14746, '域': 14712, '东': 14624, '取': 14534, '电': 14522, '技': 14510, '队': 14438, '解': 14396, '俄': 14334, '织': 14330, '常': 14304, '华': 14239, '色': 14212, '尔': 14204, '门': 14166, '快': 14126, '还': 14102, '及': 14092, '办': 14080, '精': 13914, '参': 13824, '比': 13712, '论': 13698, '应': 13590, '广': 13586, '说': 13492, '着': 13414, '步': 13358, '构': 13218, '案': 13058, '二': 12956, '届': 12950, '巴': 12926, '双': 12906, '受': 12906, '责': 12860, '李': 12824, '落': 12802, '其': 12760, '众': 12724, '情': 12700, '级': 12682, '计': 12622, '极': 12576, '都': 12576, '号': 12570, '元': 12548, '拉': 12442, '境': 12434, '可': 12402, '求': 12260, '管': 12238, '教': 12228, '省': 12188, '接': 12170, '德': 12102, '数': 12072, '气': 12036, '子': 11960, '把': 11928, '品': 11814, '打': 11776, '研': 11740, '集': 11724, '商': 11706, '贸': 11644, '投': 11592, '城': 11542, '服': 11490, '四': 11452, '罗': 11432, '策': 11368, '干': 11364, '此': 11348, '话': 11348, '态': 11292, '风': 11266, '伊': 11212, '略': 11168, '稳': 11124, '完': 11080, '车': 11060, '传': 1097 ...

# %%
orders = [0, 3, 5]
for order in orders:
    Chinese_Text_model, Chinese_Text_ngrams = markov_model(filtered_text1, order)

# %%
def generate_text(model, order, length=100):
    """使用马尔可夫模型随机生成文本"""
    generated_text = []
    prefix = random.choice(list(model.keys()))
    generated_text.extend(prefix)

    for _ in range(length - order):
        if prefix in model:
            next_char = random.choices(
                list(model[prefix].keys()),
                list(model[prefix].values())
            )[0]
            generated_text.append(next_char)
            prefix = prefix[1:] + next_char
        else:
            prefix = random.choice(list(model.keys()))
            generated_text.extend(prefix)

    return ''.join(generated_text[:length])

# %%
print(generate_text(Chinese_Text_model, 5, 200))
# Out:
# 村党总支在搭建这个大数据平台他们目前已售出的多万台工程装备如今在什么位置是什么运行状态都一目了然现在医疗云覆盖到乡老百姓远程看病更方便工业云正用大数据改善政府服务满足群众需求决定建设福厦泉与合芜蚌两个国家自主创新示范区建设正式启动日前东盟与中日韩领导人会议日在泰国曼谷唐人街拉开帷幕泰国诗琳通公主亲自拉下了庆典启动闸门中泰两国的艺术家共同演唱的歌剧选段凯旋进行曲和今夜无人入睡中落下帷幕现场洋溢着欢乐
